# %%
import numpy as np
from sklearn.cluster import SpectralClustering
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define fuzzy variables and membership functions
data_transfer_time_ratio = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Data transfer time ratio')
vm_load = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Virtual Machine load')
data_availability = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Data availability')
provider_profit = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Provider profit')
placement_potential = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'Placement potential')

# Define fuzzy membership functions
data_transfer_time_ratio.automf(3)
vm_load.automf(3)
data_availability.automf(3)
provider_profit.automf(3)
placement_potential.automf(5)

# Define fuzzy rules
rule1 = ctrl.Rule(data_transfer_time_ratio['poor'] & vm_load['poor'] & data_availability['poor'] & provider_profit['poor'], placement_potential['poor'])
rule2 = ctrl.Rule(data_transfer_time_ratio['poor'] & vm_load['average'] & data_availability['poor'] & provider_profit['average'], placement_potential['mediocre'])
rule3 = ctrl.Rule(data_transfer_time_ratio['average'] & vm_load['average'] & data_availability['poor'] & provider_profit['average'], placement_potential['average'])
rule4 = ctrl.Rule(data_transfer_time_ratio['average'] & vm_load['average'] & data_availability['average'] & provider_profit['average'], placement_potential['decent'])
rule5 = ctrl.Rule(data_transfer_time_ratio['good'] & vm_load['good'] & data_availability['average'] & provider_profit['good'], placement_potential['good'])

# Create and simulate fuzzy inference system
replication_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5])
replication_sim = ctrl.ControlSystemSimulation(replication_ctrl)

# Define cloud providers and their prices
cloud_providers = {
    'Provider 1': {'CPU': 0.020, 'Storage': 0.006, 'BW': 0.001},
    'Provider 2': {'CPU': 0.020, 'Storage': 0.0096, 'BW': 0.001},
    'Provider 3': {'CPU': 0.0095, 'Storage': 0.0012, 'BW': 0.001},
}

# Replica placement logic
def place_replica(provider_prices, placement_result):
    best_provider = max(provider_prices, key=lambda provider: placement_result)
    return best_provider

# Implement spectral clustering for data identification
def spectral_clustering(data, k):
    spectral = SpectralClustering(n_clusters=k, affinity='nearest_neighbors', n_neighbors=10)
    labels = spectral.fit_predict(data)
    return labels

# Simulation study
def simulate_cloud_system():
    # Simulate your cloud system and obtain data related to SLA violations

    # Implement spectral clustering for data identification
    data = np.random.rand(100, 4)  # Replace with your actual data
    k_clusters = 3
    data_labels = spectral_clustering(data, k_clusters)

    # Iterate through identified clusters and apply fuzzy inference for replica placement
    for cluster_label in range(k_clusters):
        cluster_data = data[data_labels == cluster_label]
        for data_point in cluster_data:
            replication_sim.input['Data transfer time ratio'] = data_point[0]
            replication_sim.input['Virtual Machine load'] = data_point[1]
            replication_sim.input['Data availability'] = data_point[2]
            replication_sim.input['Provider profit'] = data_point[3]

            replication_sim.compute()

            # Get the result and use it for replica placement
            placement_result = replication_sim.output['Placement potential']
            
            # Implement replica placement logic using placement_result
            selected_provider = place_replica(cloud_providers, placement_result)
            
            # Print or use the selected provider for replica placement
            print(f"Replica for data point {data_point} placed on {selected_provider}")

# Call the simulation function
simulate_cloud_system()
# Out:
# Replica for data point [0.83214759 0.89913405 0.71839856 0.55756622] placed on Provider 1
# Replica for data point [0.03843558 0.93181397 0.15019862 0.39930814] placed on Provider 1
# Replica for data point [0.16058031 0.98277267 0.07002781 0.26285823] placed on Provider 1
# Replica for data point [0.01133959 0.66403169 0.59487431 0.79278985] placed on Provider 1
# Replica for data point [0.44930883 0.7606783  0.08740094 0.56493345] placed on Provider 1
# Replica for data point [0.33810888 0.7679142  0.24405705 0.56187943] placed on Provider 1
# Replica for data point [0.1004008  0.94543547 0.55373862 0.8673183 ] placed on Provider 1
# Replica for data point [0.30794047 0.95164707 0.26841878 0.0972554 ] placed on Provider 1
# Replica for data point [0.09631313 0.97371978 0.08533883 0.91110754] placed on Provider 1
# Replica for data point [0.2385917  0.75506616 0.67255027 0.56865137] placed on Provider 1
# Replica for data point [0.29573538 0.48427538 0.39140061 0.62077741] placed on Provider 1
# Replica for data point [0.33772844 0.69556885 0.94544856 0.07922483] placed on Provider 1
# Replica for data point [0.6388871  0.78704435 0.04220673 0.26738699] placed on Provider 1
# Replica for data point [0.34855884 0.53053143 0.29054795 0.6889778 ] placed on Provider 1
# Replica for data point [0.12652292 0.57038192 0.21664379 0.20427225] placed on Provider 1
# Replica for data point [0.52219801 0.73628614 0.56452426 0.7014375 ] placed on Provider 1
# Replica for data point [0.5276518  0.84907471 0.01913456 0.46851428] placed on Provider 1
# Replica for data point [0.223401   0.5846174  0.59932472 0.79955814] placed on Provider 1
# Replica for data point [0.00868372 0.93129945 0.45230048 0.49082482] placed on Provider 1
# Replica for data point [0.47306729 0.57283675 0.96690736 0.77160297] placed on Provider 1
# Replica for data point [0.28388052 0.66751523 0.59478061 0.08647988] placed on Provider 1
# Replica for data point [0.49690824 0.99497332 0.24770866 0.93994571] placed on Provider 1
# Replica for data point [0.32707095 0.92995328 0.81390393 0.539368  ] placed on Provider 1
# Replica for data point [3.20599094e-04 7.36865693e-01 6.71382951e-01 6.38405191e-01] placed on Provider 1
# Replica for data point [0.4171182  0.9318748  0.94044412 0.41664371] placed on Provider 1
# Replica for data point [0.52502408 0.77725279 0.20983848 0.68633067] placed on Provider 1
# Replica for data point [0.45477392 0.9346075  0.40770953 0.83051094] placed on Provider 1
# Replica for data point [0.07433559 0.44214834 0.08959053 0.9419915 ] placed on Provider 1
# Replica for data point [0.47441361 0.76169123 0.85546098 0.87967588] placed on Provider 1
# Replica for data point [0.3012457  0.93685865 0.90588666 0.28021222] placed on Provider 1
# Replica for data point [0.43210215 0.99469192 0.26194346 0.56386504] placed on Provider 1
# Replica for data point [0.34391686 0.78071576 0.89782826 0.68671173] placed on Provider 1
# Replica for data point [0.38852166 0.92018799 0.79639507 0.00775851] placed on Provider 1
# Replica for data point [0.10058129 0.74321295 0.37265414 0.7698213 ] placed on Provider 1
# Replica for data point [0.70557137 0.8364726  0.31208954 0.86399849] placed on Provider 1
# Replica for data point [0.40518482 0.99896459 0.47271107 0.65215205] placed on Provider 1
# Replica for data point [0.77598244 0.88276978 0.66677084 0.75664497] placed on Provider 1
# Replica for data point [0.48375088 0.65060619 0.44810745 0.20276433] placed on Provider 1
# Replica for data point [0.0931391  0.59257731 0.38665825 0.99223728] placed on Provider 1
# Replica for data point [0.06420201 0.85666175 0.42808415 0.02879879] placed on Provider 1
# Replica for data point [0.84502847 0.46996803 0.98430292 0.13912803] placed on Provider 1
# Replica for data point [0.5280382  0.11027563 0.83144307 0.48554773] placed on Provider 1
# Replica for data point [0.62612623 0.13666405 0.78789176 0.9000012 ] placed on Provider 1
# Replica for data point [0.15781948 0.38547674 0.76494406 0.49834173] placed on Provider 1
# Replica for data point [0.52488916 0.1302761  0.67268975 0.10380416] placed on Provider 1
# Replica for data point [0.40915001 0.32745087 0.93941899 0.35354977] placed on Provider 1
# Replica for data point [0.78424306 0.25327675 0.656937   0.28441907] placed on Provider 1
# Replica for data point [0.44040436 0.06933751 0.56601978 0.01865544] placed on Provider 1
# Replica for data point [0.12102309 0.02003054 0.57950761 0.57538298] placed on Provider 1
# Replica for data point [0.35524614 0.21127651 0.65468877 0.42325818] placed on Provider 1
# Replica for data point [0.12430936 0.27657016 0.504353   0.07573763] placed on Provider 1
# Replica for data point [0.40582406 0.21103649 0.83402171 0.56682922] placed on Provider 1
# Replica for data point [0.35802324 0.42191214 0.08080103 0.04384279] placed on Provider 1
# Replica for data point [0.0848837  0.38079412 0.1319928  0.24593178] placed on Provider 1
# Replica for data point [0.26449311 0.16608828 0.51985116 0.30656595] placed on Provider 1
# Replica for data point [0.91405676 0.05641792 0.93954534 0.2849725 ] placed on Provider 1
# Replica for data point [0.43825954 0.09111012 0.89174482 0.67889289] placed on Provider 1
# Replica for data point [0.3246782  0.28919904 0.65312111 0.15307835] placed on Provider 1
# Replica for data point [0.30522593 0.0108085  0.3293592  0.09172513] placed on Provider 1
# Replica for data point [0.92583364 0.12992428 0.96610873 0.17462256] placed on Provider 1
# Replica for data point [0.48654936 0.43876565 0.55078534 0.13923876] placed on Provider 1
# Replica for data point [0.11315561 0.19519874 0.18401301 0.44034824] placed on Provider 1
# Replica for data point [0.05501128 0.12688692 0.90754843 0.02341034] placed on Provider 1
# Replica for data point [0.9404819  0.13457262 0.82310058 0.64187519] placed on Provider 1
# Replica for data point [0.73746115 0.09217213 0.81089622 0.30417817] placed on Provider 1
# Replica for data point [0.68032674 0.08760923 0.74581009 0.43084788] placed on Provider 1
# Replica for data point [0.14038973 0.24200415 0.46761637 0.26973858] placed on Provider 1
# Replica for data point [0.25341946 0.31507821 0.39297966 0.72526491] placed on Provider 1
# Replica for data point [0.76323617 0.31859082 0.22117409 0.42046011] placed on Provider 1
# Replica for data point [0.45148485 0.31227264 0.18122206 0.8113934 ] placed on Provider 1
# Replica for data point [0.60536483 0.18017152 0.23685201 0.96372307] placed on Provider 1
# Replica for data point [0.950652   0.75755304 0.18835102 0.68166989] placed on Provider 1
# Replica for data point [0.89799501 0.51184927 0.41898814 0.30429696] placed on Provider 1
# Replica for data point [0.95154553 0.4292145  0.32729397 0.73853133] placed on Provider 1
# Replica for data point [0.85635594 0.75728271 0.59296882 0.65972113] placed on Provider 1
# Replica for data point [0.79234711 0.7022616  0.19045579 0.42918063] placed on Provider 1
# Replica for data point [0.3673955  0.35536135 0.33314782 0.44770682] placed on Provider 1
# Replica for data point [0.72923188 0.32423202 0.45148242 0.99170052] placed on Provider 1
# Replica for data point [0.78477201 0.68784817 0.6492423  0.74314425] placed on Provider 1
# Replica for data point [0.82542966 0.44702252 0.0458161  0.43671176] placed on Provider 1
# Replica for data point [0.89476378 0.2060332  0.2095816  0.84006212] placed on Provider 1
# Replica for data point [0.99453051 0.52847029 0.52407633 0.36349486] placed on Provider 1
# Replica for data point [0.93509395 0.44702194 0.97617539 0.6892792 ] placed on Provider 1
# Replica for data point [0.58697388 0.22504909 0.67269039 0.93953803] placed on Provider 1
# Replica for data point [0.85007788 0.35081518 0.52535739 0.68998803] placed on Provider 1
# Replica for data point [0.71454431 0.30414675 0.10708585 0.21485248] placed on Provider 1
# Replica for data point [0.22607797 0.0442686  0.02611546 0.72585459] placed on Provider 1
# Replica for data point [0.77857056 0.39927471 0.8252601  0.89539138] placed on Provider 1
# Replica for data point [0.69224137 0.19803741 0.26105277 0.63484657] placed on Provider 1
# Replica for data point [0.49302236 0.42511379 0.33710828 0.51024104] placed on Provider 1
# Replica for data point [0.81396905 0.4727337  0.76628634 0.61121253] placed on Provider 1
# Replica for data point [0.07319256 0.02998309 0.11026841 0.94622586] placed on Provider 1
# Replica for data point [0.42740979 0.06586767 0.28126694 0.70132896] placed on Provider 1
# Replica for data point [0.73062538 0.37515783 0.48274595 0.51036651] placed on Provider 1
# Replica for data point [0.93476439 0.63506534 0.11386256 0.66440811] placed on Provider 1
# Replica for data point [0.88115953 0.31153805 0.09898613 0.74085197] placed on Provider 1
# Replica for data point [0.89303162 0.68780346 0.99290336 0.44032496] placed on Provider 1
# Replica for data point [0.58756852 0.03586916 0.18515925 0.28244504] placed on Provider 1
# Replica for data point [0.51128921 0.20832395 0.20681694 0.66630276] placed on Provider 1
# Replica for data point [0.66151746 0.00941256 0.22583456 0.63878778] placed on Provider 1

# %%
import numpy as np
from sklearn.cluster import SpectralClustering
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define fuzzy variables and membership functions
data_transfer_time_ratio = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Data transfer time ratio')
vm_load = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Virtual Machine load')
data_availability = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Data availability')
provider_profit = ctrl.Antecedent(np.arange(0, 1.1, 0.1), 'Provider profit')
placement_potential = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'Placement potential')

# Define fuzzy membership functions
data_transfer_time_ratio.automf(3)
vm_load.automf(3)
data_availability.automf(3)
provider_profit.automf(3)
placement_potential.automf(5)

# Define fuzzy rules
rule1 = ctrl.Rule(data_transfer_time_ratio['poor'] & vm_load['poor'] & data_availability['poor'] & provider_profit['poor'], placement_potential['poor'])
rule2 = ctrl.Rule(data_transfer_time_ratio['poor'] & vm_load['average'] & data_availability['poor'] & provider_profit['average'], placement_potential['mediocre'])
rule3 = ctrl.Rule(data_transfer_time_ratio['average'] & vm_load['average'] & data_availability['poor'] & provider_profit['average'], placement_potential['average'])
rule4 = ctrl.Rule(data_transfer_time_ratio['average'] & vm_load['average'] & data_availability['average'] & provider_profit['average'], placement_potential['decent'])
rule5 = ctrl.Rule(data_transfer_time_ratio['good'] & vm_load['good'] & data_availability['average'] & provider_profit['good'], placement_potential['good'])

# Create and simulate fuzzy inference system
replication_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5])
replication_sim = ctrl.ControlSystemSimulation(replication_ctrl)

# Define cloud providers, their regions, and prices
cloud_providers = {
    'Provider 1': {
        'US': {'CPU': 0.020, 'Storage': 0.006, 'BW': 0.001},
        'EU': {'CPU': 0.025, 'Storage': 0.006, 'BW': 0.0015},
        'AS': {'CPU': 0.027, 'Storage': 0.0066, 'BW': 0.002}
    },
    'Provider 2': {
        'US': {'CPU': 0.020, 'Storage': 0.0096, 'BW': 0.001},
        'EU': {'CPU': 0.018, 'Storage': 0.0096, 'BW': 0.0015},
        'AS': {'CPU': 0.020, 'Storage': 0.0096, 'BW': 0.002}
    },
    'Provider 3': {
        'US': {'CPU': 0.0095, 'Storage': 0.0012, 'BW': 0.001},
        'EU': {'CPU': 0.009, 'Storage': 0.0096, 'BW': 0.0015},
        'AS': {'CPU': 0.008, 'Storage': 0.009, 'BW': 0.002}
    },
}

# Replica placement logic
def place_replica(provider_prices, placement_result):
    best_provider = max(provider_prices, key=lambda provider: placement_result[provider])
    return best_provider

# Implement spectral clustering for data identification
def spectral_clustering(data, k):
    # Adjust the spectral clustering parameters
    spectral = SpectralClustering(n_clusters=k_clusters, affinity='rbf', gamma=1.0, n_neighbors=15)
    labels = spectral.fit_predict(data)
    return labels

# Simulate cloud system and obtain data related to SLA violations
def simulate_cloud_system():
    cloud_data = []
    for provider_id, (provider_name, regions) in enumerate(cloud_providers.items(), start=1):
        for region_name, prices in regions.items():
            num_data_centers = np.random.randint(2, 6)
            for dc_id in range(1, num_data_centers + 1):
                for vm_id in range(1, 9):
                    num_tasks = np.random.randint(1000, 10001)
                    for task_id in range(1, num_tasks + 1):
                        task_size = np.random.randint(200, 1001)
                        num_data = np.random.randint(300, 1001)

                        response_time = np.random.randint(120, 241)
                        availability = np.random.uniform(0.9, 1.0)

                        sla_violation = (
                            response_time > 180 or
                            availability < 0.95
                        )

                        cloud_data.append({
                            'provider_id': provider_id,
                            'region_name': region_name,
                            'dc_id': dc_id,
                            'vm_id': vm_id,
                            'task_id': task_id,
                            'task_size': task_size,
                            'num_data': num_data,
                            'response_time': response_time,
                            'availability': availability,
                            'sla_violation': sla_violation
                        })

    return cloud_data

# Call the simulation function
cloud_data = simulate_cloud_system()

# Identify data points likely to cause SLA violations using spectral clustering
data_for_clustering = np.array([
    [data_point['response_time'], data_point['availability']] for data_point in cloud_data
])

k_clusters = 3  # Number of clusters
data_labels = spectral_clustering(data_for_clustering, k_clusters)

# Iterate through identified clusters and apply fuzzy inference for replica placement
for cluster_label in range(k_clusters):
    cluster_data = [cloud_data[i] for i, label in enumerate(data_labels) if label == cluster_label]
    for data_point in cluster_data:
        replication_sim.input['Data transfer time ratio'] = data_point['response_time'] / 240  # Normalize to [0, 1]
        replication_sim.input['Virtual Machine load'] = data_point['vm_id'] / 8  # Normalize to [0, 1]
        replication_sim.input['Data availability'] = data_point['availability']
        replication_sim.input['Provider profit'] = cloud_providers[f"Provider {data_point['provider_id']}"][
            data_point['region_name']]['CPU']  # Use CPU price as a proxy for profit

        replication_sim.compute()

        # Get the result and use it for replica placement
        placement_result = {}
        for region, provider_prices in cloud_providers.items():
            replication_sim.input['Placement potential'] = replication_sim.output['Placement potential']
            placement_result[region] = replication_sim.output['Placement potential']

        # Implement replica placement logic using placement_result
        selected_provider = place_replica(placement_result, placement_result)

        # Print or use the selected provider for replica placement
        print(f"Replica for data point {data_point} placed on {selected_provider}")
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\YANSILIYU\devProject\malaria_parasite_pred\fuzzy-SLA\algorithms.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=100'>101</a> data_for_clustering = np.array([
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=101'>102</a>     [data_point['response_time'], data_point['availability']] for data_point in cloud_data
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=102'>103</a> ])
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=104'>105</a> k_clusters = 3  # Number of clusters
# --> <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=105'>106</a> data_labels = spectral_clustering(data_for_clustering, k_clusters)
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=107'>108</a> # Iterate through identified clusters and apply fuzzy inference for replica placement
#     <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=108'>109</a> for cluster_label in range(k_clusters):
#
# c:\Users\YANSILIYU\devProject\malaria_parasite_pred\fuzzy-SLA\algorithms.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a> def spectral_clustering(data, k):
#      <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=56'>57</a>     spectral = SpectralClustering(n_clusters=k, affinity='nearest_neighbors', n_neighbors=10)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=57'>58</a>     labels = spectral.fit_predict(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/YANSILIYU/devProject/malaria_parasite_pred/fuzzy-SLA/algorithms.ipynb#W1sZmlsZQ%3D%3D?line=58'>59</a>     return labels
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_spectral.py:778, in SpectralClustering.fit_predict(self, X, y)
#     756 def fit_predict(self, X, y=None):
#     757     """Perform spectral clustering on `X` and return cluster labels.
#     758
#     759     Parameters
#    (...)
#     776         Cluster labels.
#     777     """
# --> 778     return super().fit_predict(X, y)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:790, in ClusterMixin.fit_predict(self, X, y)
#     772 """
#     773 Perform clustering on `X` and returns cluster labels.
#     774
#    (...)
#     786     Cluster labels.
#     787 """
#     788 # non-optimized default implementation; override when a better
#     789 # method is possible for a given clustering algorithm
# --> 790 self.fit(X)
#     791 return self.labels_
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_spectral.py:730, in SpectralClustering.fit(self, X, y)
#     721 n_components = (
#     722     self.n_clusters if self.n_components is None else self.n_components
#     723 )
#     724 # We now obtain the real valued solution matrix to the
#     725 # relaxed Ncut problem, solving the eigenvalue problem
#     726 # L_sym x = lambda x  and recovering u = D^-1/2 x.
#     727 # The first eigenvector is constant only for fully connected graphs
#     728 # and should be kept for spectral clustering (drop_first = False)
#     729 # See spectral_embedding documentation.
# --> 730 maps = spectral_embedding(
#     731     self.affinity_matrix_,
#     732     n_components=n_components,
#     733     eigen_solver=self.eigen_solver,
#     734     random_state=random_state,
#     735     eigen_tol=self.eigen_tol,
#     736     drop_first=False,
#     737 )
#     738 if self.verbose:
#     739     print(f"Computing label assignment using {self.assign_labels}")
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:313, in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     311 laplacian *= -1
#     312 v0 = _init_arpack_v0(laplacian.shape[0], random_state)
# --> 313 _, diffusion_map = eigsh(
#     314     laplacian, k=n_components, sigma=1.0, which="LM", tol=tol, v0=v0
#     315 )
#     316 embedding = diffusion_map.T[n_components::-1]
#     317 if norm_laplacian:
#     318     # recover u = D^-1/2 x from the eigenvector output x
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1697, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1695 with _ARPACK_LOCK:
#    1696     while not params.converged:
# -> 1697         params.iterate()
#    1699     return params.extract(return_eigenvectors)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:560, in _SymmetricArpackParams.iterate(self)
#     558     else:
#     559         Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 560         self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     561 elif self.ido == 2:
#     562     self.workd[yslice] = self.B(self.workd[xslice])
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\linalg\_interface.py:234, in LinearOperator.matvec(self, x)
#     231 if x.shape != (N,) and x.shape != (N,1):
#     232     raise ValueError('dimension mismatch')
# --> 234 y = self._matvec(x)
#     236 if isinstance(x, np.matrix):
#     237     y = asmatrix(y)
#
# File c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:928, in SpLuInv._matvec(self, x)
#     925     return (self.M_lu.solve(np.real(x).astype(self.dtype))
#     926             + 1j * self.M_lu.solve(np.imag(x).astype(self.dtype)))
#     927 else:
# --> 928     return self.M_lu.solve(x.astype(self.dtype))
#
# KeyboardInterrupt:
