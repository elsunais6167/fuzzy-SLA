# %%
import simpy
import random

class VirtualMachine:
    def __init__(self, env, id, processing_capability, num_cpus, ram, storage_capacity, data_center):
        self.env = env
        self.id = id
        self.processing_capability = processing_capability
        self.num_cpus = num_cpus
        self.ram = ram
        self.storage_capacity = storage_capacity
        self.data_center = data_center

    def process_task(self, task, target_dc, data_transfer_time=0):
        total_processing_time = task['size'] / self.processing_capability + data_transfer_time
        yield self.env.timeout(total_processing_time)
        cost = self.data_center.calculate_cost(task['size'], target_dc)
        print(f"VM {self.id} completed task {task['id']} at time {self.env.now}, cost: ${cost:.2f}")

class DataCenter:
    def __init__(self, env, id, num_vms, vm_specs, pricing, bw_params):
        self.env = env
        self.id = id
        self.vm_specs = vm_specs
        self.pricing = pricing
        self.bw_params = bw_params
        self.vms = [VirtualMachine(env, f"VM_{id}_{i}", **vm_specs, data_center=self) for i in range(num_vms)]

    def calculate_cost(self, task_size, target_dc):
        cpu_cost = task_size / 107 * self.pricing['cpu_price']
        storage_cost = self.vm_specs['storage_capacity'] * self.pricing['storage_price']

        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_dc']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_region']
        else:
            # Inter-region transfer
            bw_cost = task_size * self.pricing['bw_price']['inter_region']

        return cpu_cost + storage_cost + bw_cost

    def calculate_data_transfer_time(self, task_size, target_dc):
        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_capacity = self.bw_params['intra_dc']['capacity']
            bw_delay = self.bw_params['intra_dc']['delay']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_capacity = self.bw_params['intra_region']['capacity']
            bw_delay = self.bw_params['intra_region']['delay']
        else:
            # Inter-region transfer
            bw_capacity = self.bw_params['inter_region']['capacity']
            bw_delay = self.bw_params['inter_region']['delay']

        data_transfer_time = task_size / bw_capacity + bw_delay / 1000  # Convert delay from ms to seconds
        return data_transfer_time

class CloudProvider:
    def __init__(self, env, id, num_regions, dcs_per_region, vm_specs, pricing, bw_params):
        self.env = env
        self.id = id
        self.pricing = pricing
        self.bw_params = bw_params
        region_keys = list(pricing.keys())  # Get the region keys from pricing
        self.regions = [DataCenter(env, f"DC_{id}_{region_keys[r]}", random.randint(*dcs_per_region), vm_specs, pricing[region_keys[r]], bw_params) for r in range(num_regions)]

    def find_target_dc(self, task):
        # Simplified logic: Randomly select a data center
        return random.choice(self.regions)

# Bandwidth parameters
bw_params = {
    'inter_region': {'capacity': 500, 'delay': 150},
    'intra_region': {'capacity': 1000, 'delay': 50},
    'intra_dc': {'capacity': 8000, 'delay': 10}
}

# Simulation parameters
num_providers = 3
num_regions = 3
dcs_per_provider = (2, 5)
num_vms_per_dc = 8
vm_specs = {
    'processing_capability': 1500,  # in MIPS
    'num_cpus': 2,
    'ram': 4,  # in Gb
    'storage_capacity': 8  # in Gb
}
num_data = 200
task_size_range = (200, 1000)  # Task size range in MI

# Pricing structure
pricing = {
    'Provider_1': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.025, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.027, 'storage_price': 0.0066, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_2': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.018, 'storage_price': 0.008, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_3': {
        'US': {'cpu_price': 0.0095, 'storage_price': 0.0012, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.0090, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.0080, 'storage_price': 0.0090, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    }
}

env = simpy.Environment()

providers = []
for i in range(num_providers):
    provider_key = f'Provider_{i+1}'  # This should match the keys in the pricing dictionary
    if provider_key in pricing:
        provider = CloudProvider(env, provider_key, num_regions, dcs_per_provider, vm_specs, pricing[provider_key], bw_params)
        providers.append(provider)
    else:
        print(f"Warning: Pricing not found for {provider_key}")
        
tasks = [{'id': i, 'size': random.randint(*task_size_range)} for i in range(num_data)]

for task in tasks:
    # Example logic for selecting source and target data centers
    random_provider = random.choice(providers)
    source_dc = random.choice(random_provider.regions)
    target_dc = random.choice(random_provider.regions)
    data_transfer_time = source_dc.calculate_data_transfer_time(task['size'], target_dc)
    random_vm = random.choice(target_dc.vms)
    env.process(random_vm.process_task(task, target_dc, data_transfer_time))

env.run()
# Out:
# VM VM_DC_Provider_2_EU_2 completed task 114 at time 0.16912500000000003, cost: $0.40
# VM VM_DC_Provider_1_EU_0 completed task 21 at time 0.1715, cost: $0.40
# VM VM_DC_Provider_1_AS_1 completed task 56 at time 0.18495833333333334, cost: $0.55
# VM VM_DC_Provider_2_US_2 completed task 161 at time 0.1897083333333333, cost: $0.35
# VM VM_DC_Provider_2_AS_1 completed task 134 at time 0.192875, cost: $0.58
# VM VM_DC_Provider_3_EU_0 completed task 123 at time 0.19445833333333332, cost: $0.45
# VM VM_DC_Provider_1_AS_2 completed task 102 at time 0.20633333333333334, cost: $0.61
# VM VM_DC_Provider_2_US_2 completed task 62 at time 0.20870833333333333, cost: $0.37
# VM VM_DC_Provider_3_US_0 completed task 155 at time 0.20870833333333333, cost: $0.28
# VM VM_DC_Provider_1_EU_0 completed task 181 at time 0.23008333333333333, cost: $0.53
# VM VM_DC_Provider_1_US_2 completed task 140 at time 0.26095833333333335, cost: $0.42
# VM VM_DC_Provider_3_AS_2 completed task 199 at time 0.26966666666666667, cost: $0.75
# VM VM_DC_Provider_1_AS_0 completed task 35 at time 0.2791666666666667, cost: $0.82
# VM VM_DC_Provider_3_EU_0 completed task 48 at time 0.32508333333333334, cost: $0.71
# VM VM_DC_Provider_2_AS_2 completed task 72 at time 0.3274583333333333, cost: $0.95
# VM VM_DC_Provider_3_EU_0 completed task 137 at time 0.3274583333333333, cost: $0.71
# VM VM_DC_Provider_3_EU_1 completed task 112 at time 0.330625, cost: $0.72
# VM VM_DC_Provider_2_AS_0 completed task 146 at time 0.33616666666666667, cost: $0.98
# VM VM_DC_Provider_3_AS_2 completed task 158 at time 0.34724999999999995, cost: $0.96
# VM VM_DC_Provider_3_EU_1 completed task 17 at time 0.363875, cost: $0.78
# VM VM_DC_Provider_2_EU_3 completed task 144 at time 0.38366666666666666, cost: $0.85
# VM VM_DC_Provider_3_US_1 completed task 39 at time 0.39079166666666665, cost: $0.53
# VM VM_DC_Provider_3_US_1 completed task 124 at time 0.39079166666666665, cost: $0.53
# VM VM_DC_Provider_1_AS_0 completed task 119 at time 0.3963333333333333, cost: $1.15
# VM VM_DC_Provider_1_US_1 completed task 2 at time 0.40504166666666663, cost: $0.64
# VM VM_DC_Provider_3_EU_1 completed task 178 at time 0.40504166666666663, cost: $0.87
# VM VM_DC_Provider_3_AS_0 completed task 191 at time 0.41375, cost: $1.13
# VM VM_DC_Provider_2_EU_0 completed task 55 at time 0.41770833333333335, cost: $0.92
# VM VM_DC_Provider_1_AS_1 completed task 151 at time 0.420875, cost: $1.22
# VM VM_DC_Provider_3_EU_1 completed task 27 at time 0.4216666666666667, cost: $0.43
# VM VM_DC_Provider_1_US_2 completed task 24 at time 0.42404166666666665, cost: $0.67
# VM VM_DC_Provider_3_US_1 completed task 188 at time 0.4316666666666667, cost: $0.26
# VM VM_DC_Provider_3_US_0 completed task 195 at time 0.4316666666666667, cost: $0.26
# VM VM_DC_Provider_1_US_2 completed task 131 at time 0.4335416666666667, cost: $0.68
# VM VM_DC_Provider_3_US_0 completed task 82 at time 0.4406666666666667, cost: $0.60
# VM VM_DC_Provider_1_US_0 completed task 171 at time 0.447, cost: $0.70
# VM VM_DC_Provider_3_US_1 completed task 91 at time 0.45166666666666666, cost: $0.27
# VM VM_DC_Provider_1_US_1 completed task 83 at time 0.45499999999999996, cost: $0.34
# VM VM_DC_Provider_1_AS_2 completed task 157 at time 0.46125, cost: $1.34
# VM VM_DC_Provider_2_EU_4 completed task 165 at time 0.4633333333333333, cost: $0.48
# VM VM_DC_Provider_1_AS_0 completed task 101 at time 0.46758333333333335, cost: $1.35
# VM VM_DC_Provider_1_EU_0 completed task 73 at time 0.4683333333333333, cost: $0.48
# VM VM_DC_Provider_3_EU_0 completed task 70 at time 0.4691666666666666, cost: $1.00
# VM VM_DC_Provider_3_AS_1 completed task 138 at time 0.475, cost: $0.60
# VM VM_DC_Provider_3_EU_0 completed task 162 at time 0.47550000000000003, cost: $1.01
# VM VM_DC_Provider_1_AS_1 completed task 81 at time 0.48895833333333333, cost: $1.42
# VM VM_DC_Provider_2_US_1 completed task 52 at time 0.49212500000000003, cost: $0.80
# VM VM_DC_Provider_3_AS_1 completed task 184 at time 0.49291666666666667, cost: $1.34
# VM VM_DC_Provider_2_AS_1 completed task 168 at time 0.4960833333333333, cost: $1.42
# VM VM_DC_Provider_3_AS_2 completed task 143 at time 0.5047916666666666, cost: $1.37
# VM VM_DC_Provider_2_EU_3 completed task 90 at time 0.506375, cost: $1.11
# VM VM_DC_Provider_1_AS_1 completed task 41 at time 0.5133333333333333, cost: $0.68
# VM VM_DC_Provider_3_AS_2 completed task 108 at time 0.5133333333333333, cost: $0.65
# VM VM_DC_Provider_3_US_0 completed task 139 at time 0.5249999999999999, cost: $0.32
# VM VM_DC_Provider_3_AS_1 completed task 164 at time 0.525375, cost: $1.42
# VM VM_DC_Provider_1_AS_0 completed task 172 at time 0.5266666666666666, cost: $0.70
# VM VM_DC_Provider_1_AS_2 completed task 87 at time 0.53, cost: $0.70
# VM VM_DC_Provider_3_US_0 completed task 49 at time 0.5309166666666667, cost: $0.73
# VM VM_DC_Provider_1_EU_4 completed task 29 at time 0.53725, cost: $1.20
# VM VM_DC_Provider_1_US_3 completed task 34 at time 0.5380416666666666, cost: $0.84
# VM VM_DC_Provider_1_AS_1 completed task 186 at time 0.5467500000000001, cost: $1.58
# VM VM_DC_Provider_1_EU_4 completed task 177 at time 0.5483333333333333, cost: $0.57
# VM VM_DC_Provider_1_US_1 completed task 16 at time 0.5530833333333334, cost: $0.86
# VM VM_DC_Provider_2_AS_2 completed task 150 at time 0.5549999999999999, cost: $0.74
# VM VM_DC_Provider_2_US_1 completed task 9 at time 0.55625, cost: $0.90
# VM VM_DC_Provider_1_US_1 completed task 5 at time 0.5665416666666667, cost: $0.88
# VM VM_DC_Provider_2_AS_2 completed task 92 at time 0.5673333333333334, cost: $1.62
# VM VM_DC_Provider_1_AS_1 completed task 175 at time 0.5866666666666667, cost: $0.78
# VM VM_DC_Provider_1_US_1 completed task 1 at time 0.5902916666666667, cost: $0.92
# VM VM_DC_Provider_2_US_0 completed task 111 at time 0.5926666666666667, cost: $0.95
# VM VM_DC_Provider_3_AS_1 completed task 15 at time 0.6029583333333334, cost: $1.63
# VM VM_DC_Provider_2_US_2 completed task 149 at time 0.60375, cost: $0.97
# VM VM_DC_Provider_3_US_0 completed task 103 at time 0.62, cost: $0.38
# VM VM_DC_Provider_3_EU_0 completed task 11 at time 0.6259166666666667, cost: $1.31
# VM VM_DC_Provider_1_EU_1 completed task 25 at time 0.63, cost: $0.65
# VM VM_DC_Provider_3_US_0 completed task 84 at time 0.6377916666666666, cost: $0.87
# VM VM_DC_Provider_2_EU_1 completed task 197 at time 0.6499999999999999, cost: $0.66
# VM VM_DC_Provider_1_AS_1 completed task 37 at time 0.655, cost: $0.87
# VM VM_DC_Provider_2_EU_3 completed task 148 at time 0.6699999999999999, cost: $0.68
# VM VM_DC_Provider_3_EU_0 completed task 135 at time 0.6781666666666666, cost: $1.41
# VM VM_DC_Provider_1_AS_1 completed task 58 at time 0.6816666666666666, cost: $0.91
# VM VM_DC_Provider_3_AS_0 completed task 12 at time 0.685, cost: $0.86
# VM VM_DC_Provider_2_EU_1 completed task 7 at time 0.69, cost: $0.70
# VM VM_DC_Provider_2_AS_1 completed task 42 at time 0.6933333333333334, cost: $0.92
# VM VM_DC_Provider_3_AS_2 completed task 118 at time 0.6955833333333333, cost: $1.87
# VM VM_DC_Provider_1_US_0 completed task 193 at time 0.7150000000000001, cost: $0.52
# VM VM_DC_Provider_3_AS_1 completed task 192 at time 0.7217083333333334, cost: $1.94
# VM VM_DC_Provider_1_US_1 completed task 194 at time 0.7217083333333334, cost: $1.12
# VM VM_DC_Provider_1_EU_4 completed task 176 at time 0.7333333333333333, cost: $0.76
# VM VM_DC_Provider_3_US_1 completed task 129 at time 0.74, cost: $0.46
# VM VM_DC_Provider_3_AS_0 completed task 189 at time 0.7416666666666667, cost: $0.93
# VM VM_DC_Provider_1_US_2 completed task 106 at time 0.7422916666666667, cost: $1.15
# VM VM_DC_Provider_2_US_1 completed task 166 at time 0.7422916666666667, cost: $1.17
# VM VM_DC_Provider_1_EU_1 completed task 183 at time 0.7494166666666667, cost: $1.67
# VM VM_DC_Provider_2_EU_4 completed task 4 at time 0.7516666666666667, cost: $0.77
# VM VM_DC_Provider_2_EU_1 completed task 121 at time 0.7541666666666667, cost: $1.63
# VM VM_DC_Provider_2_EU_1 completed task 59 at time 0.7666666666666666, cost: $0.78
# VM VM_DC_Provider_1_AS_0 completed task 99 at time 0.7715833333333333, cost: $2.22
# VM VM_DC_Provider_1_EU_2 completed task 147 at time 0.7802916666666666, cost: $1.73
# VM VM_DC_Provider_3_US_0 completed task 141 at time 0.781875, cost: $1.07
# VM VM_DC_Provider_1_AS_2 completed task 185 at time 0.7849999999999999, cost: $1.05
# VM VM_DC_Provider_2_US_1 completed task 152 at time 0.7874166666666667, cost: $1.24
# VM VM_DC_Provider_1_US_3 completed task 64 at time 0.8016666666666666, cost: $1.23
# VM VM_DC_Provider_1_US_2 completed task 54 at time 0.8083333333333333, cost: $0.59
# VM VM_DC_Provider_1_AS_2 completed task 198 at time 0.8316666666666667, cost: $1.11
# VM VM_DC_Provider_2_AS_2 completed task 117 at time 0.8383333333333334, cost: $1.11
# VM VM_DC_Provider_1_AS_1 completed task 174 at time 0.8383333333333334, cost: $1.12
# VM VM_DC_Provider_3_EU_1 completed task 44 at time 0.8783333333333334, cost: $0.86
# VM VM_DC_Provider_1_AS_2 completed task 130 at time 0.8866666666666667, cost: $1.18
# VM VM_DC_Provider_1_US_2 completed task 19 at time 0.9000000000000001, cost: $0.65
# VM VM_DC_Provider_3_EU_1 completed task 109 at time 0.9016666666666667, cost: $0.89
# VM VM_DC_Provider_3_EU_1 completed task 173 at time 0.915, cost: $0.90
# VM VM_DC_Provider_3_US_0 completed task 18 at time 0.9166666666666667, cost: $0.58
# VM VM_DC_Provider_3_AS_2 completed task 142 at time 0.9183333333333334, cost: $1.15
# VM VM_DC_Provider_1_AS_0 completed task 153 at time 0.9216666666666667, cost: $1.23
# VM VM_DC_Provider_3_US_1 completed task 76 at time 0.93, cost: $0.58
# VM VM_DC_Provider_1_AS_0 completed task 86 at time 0.9333333333333333, cost: $1.25
# VM VM_DC_Provider_2_AS_3 completed task 190 at time 0.9400000000000001, cost: $1.24
# VM VM_DC_Provider_2_EU_3 completed task 97 at time 0.9616666666666667, cost: $0.98
# VM VM_DC_Provider_1_AS_0 completed task 113 at time 0.9666666666666668, cost: $1.29
# VM VM_DC_Provider_1_AS_2 completed task 75 at time 0.9750000000000001, cost: $1.30
# VM VM_DC_Provider_2_AS_2 completed task 133 at time 0.9833333333333334, cost: $1.30
# VM VM_DC_Provider_1_AS_1 completed task 187 at time 1.0150000000000001, cost: $1.36
# VM VM_DC_Provider_1_US_1 completed task 43 at time 1.0166666666666666, cost: $0.74
# VM VM_DC_Provider_1_EU_0 completed task 169 at time 1.025, cost: $1.06
# VM VM_DC_Provider_1_AS_1 completed task 26 at time 1.0316666666666667, cost: $1.38
# VM VM_DC_Provider_3_EU_1 completed task 110 at time 1.0316666666666667, cost: $1.01
# VM VM_DC_Provider_3_US_1 completed task 107 at time 1.0416666666666667, cost: $0.66
# VM VM_DC_Provider_2_AS_3 completed task 8 at time 1.0466666666666666, cost: $1.38
# VM VM_DC_Provider_1_EU_0 completed task 63 at time 1.06, cost: $1.10
# VM VM_DC_Provider_3_US_0 completed task 89 at time 1.0633333333333335, cost: $0.67
# VM VM_DC_Provider_2_EU_2 completed task 20 at time 1.08, cost: $1.09
# VM VM_DC_Provider_1_AS_2 completed task 13 at time 1.0866666666666667, cost: $1.45
# VM VM_DC_Provider_2_EU_4 completed task 182 at time 1.1216666666666666, cost: $1.14
# VM VM_DC_Provider_1_US_2 completed task 45 at time 1.1233333333333335, cost: $0.81
# VM VM_DC_Provider_1_AS_2 completed task 46 at time 1.1533333333333333, cost: $1.54
# VM VM_DC_Provider_2_AS_0 completed task 77 at time 1.1533333333333333, cost: $1.52
# VM VM_DC_Provider_3_AS_0 completed task 88 at time 1.1733333333333333, cost: $1.47
# VM VM_DC_Provider_2_AS_1 completed task 38 at time 1.175, cost: $1.55
# VM VM_DC_Provider_1_AS_2 completed task 60 at time 1.185, cost: $1.59
# VM VM_DC_Provider_1_EU_0 completed task 65 at time 1.185, cost: $1.23
# VM VM_DC_Provider_1_EU_1 completed task 66 at time 1.195, cost: $1.24
# VM VM_DC_Provider_1_US_1 completed task 95 at time 1.2, cost: $0.87
# VM VM_DC_Provider_3_US_1 completed task 167 at time 1.2033333333333334, cost: $0.76
# VM VM_DC_Provider_3_EU_1 completed task 74 at time 1.2066666666666666, cost: $1.18
# VM VM_DC_Provider_2_EU_1 completed task 126 at time 1.21, cost: $1.23
# VM VM_DC_Provider_2_EU_0 completed task 170 at time 1.2166666666666668, cost: $1.23
# VM VM_DC_Provider_2_AS_2 completed task 22 at time 1.22, cost: $1.61
# VM VM_DC_Provider_1_US_2 completed task 33 at time 1.2366666666666668, cost: $0.89
# VM VM_DC_Provider_2_AS_3 completed task 50 at time 1.2516666666666667, cost: $1.65
# VM VM_DC_Provider_1_AS_0 completed task 156 at time 1.2533333333333334, cost: $1.68
# VM VM_DC_Provider_1_EU_1 completed task 14 at time 1.2616666666666667, cost: $1.31
# VM VM_DC_Provider_1_AS_2 completed task 32 at time 1.28, cost: $1.72
# VM VM_DC_Provider_3_US_1 completed task 57 at time 1.28, cost: $0.81
# VM VM_DC_Provider_3_EU_0 completed task 78 at time 1.2850000000000001, cost: $1.25
# VM VM_DC_Provider_2_US_1 completed task 154 at time 1.3066666666666666, cost: $0.97
# VM VM_DC_Provider_1_EU_4 completed task 80 at time 1.3433333333333333, cost: $1.39
# VM VM_DC_Provider_3_US_1 completed task 105 at time 1.36, cost: $0.87
# VM VM_DC_Provider_2_US_1 completed task 104 at time 1.3633333333333333, cost: $1.01
# VM VM_DC_Provider_3_EU_0 completed task 180 at time 1.3683333333333334, cost: $1.33
# VM VM_DC_Provider_1_US_1 completed task 98 at time 1.37, cost: $0.99
# VM VM_DC_Provider_1_EU_3 completed task 127 at time 1.3716666666666666, cost: $1.42
# VM VM_DC_Provider_2_EU_2 completed task 3 at time 1.3783333333333334, cost: $1.39
# VM VM_DC_Provider_1_AS_2 completed task 116 at time 1.3883333333333334, cost: $1.86
# VM VM_DC_Provider_1_US_3 completed task 0 at time 1.4033333333333333, cost: $1.01
# VM VM_DC_Provider_3_AS_1 completed task 69 at time 1.4166666666666665, cost: $1.77
# VM VM_DC_Provider_2_AS_1 completed task 40 at time 1.4466666666666668, cost: $1.91
# VM VM_DC_Provider_2_AS_2 completed task 68 at time 1.4533333333333334, cost: $1.92
# VM VM_DC_Provider_2_AS_2 completed task 10 at time 1.4649999999999999, cost: $1.93
# VM VM_DC_Provider_3_EU_0 completed task 159 at time 1.4849999999999999, cost: $1.44
# VM VM_DC_Provider_3_US_0 completed task 23 at time 1.4866666666666668, cost: $0.95
# VM VM_DC_Provider_3_EU_0 completed task 145 at time 1.495, cost: $1.45
# VM VM_DC_Provider_1_US_3 completed task 28 at time 1.505, cost: $1.08
# VM VM_DC_Provider_1_AS_1 completed task 36 at time 1.5150000000000001, cost: $2.03
# VM VM_DC_Provider_3_AS_1 completed task 115 at time 1.5216666666666667, cost: $1.90
# VM VM_DC_Provider_1_AS_2 completed task 61 at time 1.525, cost: $2.05
# VM VM_DC_Provider_2_EU_0 completed task 160 at time 1.5333333333333334, cost: $1.55
# VM VM_DC_Provider_3_EU_0 completed task 47 at time 1.54, cost: $1.49
# VM VM_DC_Provider_3_EU_1 completed task 51 at time 1.5516666666666667, cost: $1.50
# VM VM_DC_Provider_1_AS_2 completed task 79 at time 1.5516666666666667, cost: $2.08
# VM VM_DC_Provider_3_AS_1 completed task 196 at time 1.5583333333333336, cost: $1.95
# VM VM_DC_Provider_1_EU_1 completed task 31 at time 1.5616666666666668, cost: $1.62
# VM VM_DC_Provider_1_US_2 completed task 85 at time 1.5683333333333334, cost: $1.13
# VM VM_DC_Provider_2_EU_1 completed task 71 at time 1.5733333333333333, cost: $1.59
# VM VM_DC_Provider_2_US_0 completed task 94 at time 1.5766666666666667, cost: $1.16
# VM VM_DC_Provider_1_AS_2 completed task 128 at time 1.5766666666666667, cost: $2.12
# VM VM_DC_Provider_1_AS_2 completed task 96 at time 1.5983333333333334, cost: $2.15
# VM VM_DC_Provider_3_EU_0 completed task 6 at time 1.6216666666666666, cost: $1.57
# VM VM_DC_Provider_1_AS_0 completed task 179 at time 1.6266666666666667, cost: $2.18
# VM VM_DC_Provider_2_EU_3 completed task 125 at time 1.63, cost: $1.65
# VM VM_DC_Provider_3_EU_0 completed task 132 at time 1.6316666666666668, cost: $1.58
# VM VM_DC_Provider_1_AS_0 completed task 122 at time 1.6416666666666666, cost: $2.20
# VM VM_DC_Provider_3_AS_2 completed task 93 at time 1.6433333333333333, cost: $2.06
# VM VM_DC_Provider_2_AS_1 completed task 100 at time 1.6516666666666666, cost: $2.18
# VM VM_DC_Provider_1_US_1 completed task 120 at time 1.6666666666666665, cost: $1.20
# VM VM_DC_Provider_1_EU_0 completed task 53 at time 1.6883333333333332, cost: $1.75
# VM VM_DC_Provider_1_US_2 completed task 136 at time 1.6966666666666668, cost: $1.22
# VM VM_DC_Provider_3_US_1 completed task 30 at time 1.7066666666666666, cost: $1.09
# VM VM_DC_Provider_2_US_0 completed task 163 at time 1.7083333333333333, cost: $1.26
# VM VM_DC_Provider_1_AS_0 completed task 67 at time 1.7116666666666664, cost: $2.30
