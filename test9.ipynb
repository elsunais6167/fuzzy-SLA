# %%
import simpy
import random
from sklearn.cluster import SpectralClustering
import numpy as np

class VirtualMachine:
    def __init__(self, env, id, processing_capability, num_cpus, ram, storage_capacity, data_center, region):
        self.env = env
        self.id = id
        self.processing_capability = processing_capability
        self.num_cpus = num_cpus
        self.ram = ram
        self.storage_capacity = storage_capacity
        self.data_center = data_center
        self.region = region
        self.uptime = 0
        self.total_time = 0
        self.data_access_log = {}
    
    def update_availability(self, time_passed):
        # Call this method periodically to update uptime and total_time
        self.total_time += time_passed  # Update with the actual time passed
        
    def get_availability(self):
        if self.total_time == 0:
            return 1  # Assuming always available when no time has passed
        return self.uptime / self.total_time
    
    def process_task(self, task, target_dc, data_transfer_time=0):
        start_time = self.env.now
        total_processing_time = task['size'] / self.processing_capability + data_transfer_time
        yield self.env.timeout(total_processing_time)
        end_time = self.env.now

        # Calculate response time and check for SLA violation or near violation
        response_time = end_time - start_time
        sla_rt = 180  # SLORT in seconds
        sla_ma = 0.95  # SLOMA in seconds
        w = 0.8  # Define the weight factor
        th_rt = w * sla_rt  # Threshold for near SLA violation

        penalty = 0
        near_violation = False
        if response_time > sla_rt:
            penalty = 0.0025  # Penalty per violation
        elif response_time > th_rt:
            near_violation = True  # Task is near to causing SLA violation

        cost = self.data_center.calculate_cost(task['size'], target_dc) - penalty
        self.data_center.total_revenue += (0.7 - penalty)  # Update total revenue for the data center
        self.data_center.near_violations += int(near_violation)  # Update near violations count for the data center

        self.data_access_log[task['id']] = {
            'response_time': response_time,
            'penalty': penalty,
            'near_violation': near_violation
        }
        print(f"VM {self.id} processed Task {task['id']} - Response Time={response_time}, Penalty={penalty}, Near Violation={near_violation}")
        
    def calculate_correlation_matrix(self, data_accessed, P):
        n = len(data_accessed)
        correlation_matrix = np.zeros((n, n))

        for i in range(n):
            for j in range(n):
                if i != j:
                    # T_k(di) is the set of tasks accessing data di
                    T_k_di = data_accessed[i]['tasks']
                    T_k_dj = data_accessed[j]['tasks']
                    common_tasks = len(set(T_k_di).intersection(set(T_k_dj)))
                    correlation_matrix[i, j] = common_tasks / P
                else:
                    correlation_matrix[i, j] = 0
        return correlation_matrix

    def perform_spectral_clustering(self, correlation_matrix, K):
        # Apply spectral clustering
        sc = SpectralClustering(n_clusters=K, affinity='precomputed')
        group_labels = sc.fit_predict(correlation_matrix)
        return group_labels

    def select_data_to_replicate(self, data_accessed, group_labels):
        # Calculate average access frequency for each group
        available_vms = [vm for vm in self.data_center.vms if vm.get_availability() >= self.slo_ma]
        unique_labels = set(group_labels)
        groups = {label: [] for label in unique_labels}

        for i, label in enumerate(group_labels):
            groups[label].append(data_accessed[i])

        data_to_replicate = []

        for label, group in groups.items():
            avg_freq = sum(d['access_frequency'] for d in group) / len(group)
            data_to_replicate.extend([d for d in group if d['access_frequency'] >= avg_freq])
            data_to_replicate = [d for d in data_to_replicate if self.is_in_same_region(d)]

        return data_to_replicate
    
    def is_in_same_region(self, data_item):
        # Logic to check if the data item is frequently accessed within the same region
        return all(vm.region == self.region for vm in data_item['accessing_vms'])
    
    # Update the adjust_replicas method to include the new strategy
    def adjust_replicas(self, P, K):
        # This list is populated with actual data accessed information
        data_accessed = [{'id': d, 'access_frequency': self.data_access_log[d]['access_frequency'], 'tasks': self.data_access_log[d]['tasks']} for d in self.data_access_log]
        
        correlation_matrix = self.calculate_correlation_matrix(data_accessed, P)
        group_labels = self.perform_spectral_clustering(correlation_matrix, K)
        data_to_replicate = self.select_data_to_replicate(data_accessed, group_labels)

        for data_item in data_to_replicate:
            # Find the best VM considering both response time and availability
            best_vm = self.find_best_vm_for_replication(data_item)
    
    def find_best_vm_for_replication(self, data_item):
        # Filter VMs based on storage capacity
        suitable_vms = [vm for vm in self.data_center.vms if vm.storage_capacity >= data_item['size'] and vm.get_availability() >= self.slo_ma]

        # Prioritize VMs in the same data center or region to minimize bandwidth costs and transfer time
        same_dc_vms = [vm for vm in suitable_vms if vm.data_center.id == self.data_center.id]
        same_region_vms = [vm for vm in suitable_vms if vm.region == self.region and vm not in same_dc_vms]

        # Select the best VM based on the lowest cost, prioritizing same DC, then same region
        best_vm = None

        if same_dc_vms:
            best_vm = min(same_dc_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        elif same_region_vms:
            best_vm = min(same_region_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        else:
            best_vm = min(suitable_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center)) if suitable_vms else None

        return best_vm

class DataCenter:
    def __init__(self, env, id, num_vms, vm_specs, pricing, bw_params, region):
        self.env = env
        self.id = id
        self.vm_specs = vm_specs
        self.pricing = pricing
        self.bw_params = bw_params
        self.total_revenue = 0
        self.near_violations = 0
        self.region = region
        self.vms = [VirtualMachine(env, f"VM_{id}_{i}", **vm_specs, data_center=self, region=self.region) for i in range(num_vms)]
    
    def get_total_revenue(self):
        return self.total_revenue
    
    def get_near_violations_count(self):
        return self.near_violations
    
    def calculate_cost(self, task_size, target_dc):
        cpu_cost = task_size / 107 * self.pricing['cpu_price']
        storage_cost = self.vm_specs['storage_capacity'] * self.pricing['storage_price']

        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_dc']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_region']
        else:
            # Inter-region transfer
            bw_cost = task_size * self.pricing['bw_price']['inter_region']

        return cpu_cost + storage_cost + bw_cost

    def calculate_data_transfer_time(self, task_size, target_dc):
        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_capacity = self.bw_params['intra_dc']['capacity']
            bw_delay = self.bw_params['intra_dc']['delay']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_capacity = self.bw_params['intra_region']['capacity']
            bw_delay = self.bw_params['intra_region']['delay']
        else:
            # Inter-region transfer
            bw_capacity = self.bw_params['inter_region']['capacity']
            bw_delay = self.bw_params['inter_region']['delay']

        data_transfer_time = task_size / bw_capacity + bw_delay / 1000  # Convert delay from ms to seconds
        return data_transfer_time

class CloudProvider:
    def __init__(self, env, id, num_regions, dcs_per_region, vm_specs, pricing, bw_params):
        self.env = env
        self.id = id
        self.pricing = pricing
        self.bw_params = bw_params
        region_keys = list(pricing.keys())  # Get the region keys from pricing
        self.regions = [DataCenter(env, f"DC_{id}_{region_keys[r]}", random.randint(*dcs_per_region), vm_specs, pricing[region_keys[r]], bw_params, region=region_keys[r]) for r in range(num_regions)]
    
    def find_target_dc(self, task):
        # Simplified logic: Randomly select a data center
        return random.choice(self.regions)

# Bandwidth parameters
bw_params = {
    'inter_region': {'capacity': 500, 'delay': 150},
    'intra_region': {'capacity': 1000, 'delay': 50},
    'intra_dc': {'capacity': 8000, 'delay': 10}
}

# Simulation parameters
num_providers = 3
num_regions = 3
dcs_per_provider = (2, 5)
num_vms_per_dc = 8
vm_specs = {
    'processing_capability': 1500,  # in MIPS
    'num_cpus': 2,
    'ram': 4,  # in Gb
    'storage_capacity': 8  # in Gb
}
num_data = 200
task_size_range = (200, 1000)  # Task size range in MI

# Pricing structure
pricing = {
    'Provider_1': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.025, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.027, 'storage_price': 0.0066, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_2': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.018, 'storage_price': 0.008, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_3': {
        'US': {'cpu_price': 0.0095, 'storage_price': 0.0012, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.0090, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.0080, 'storage_price': 0.0090, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    }
}

env = simpy.Environment()
P = 32 # Number of violating tasks
K = 3 #Number of Cluster

providers = []
for i in range(num_providers):
    provider_key = f'Provider_{i+1}'  # This should match the keys in the pricing dictionary
    if provider_key in pricing:
        provider = CloudProvider(env, provider_key, num_regions, dcs_per_provider, vm_specs, pricing[provider_key], bw_params)
        providers.append(provider)
    else:
        print(f"Warning: Pricing not found for {provider_key}")
        
tasks = [{'id': i, 'size': random.randint(*task_size_range)} for i in range(num_data)]

#for provider in providers:
    #for dc in provider.regions:
        #print(f"Data Center {dc.id}: Total Revenue={dc.get_total_revenue()}, Near Violations={dc.get_near_violations_count()}")

for task in tasks:
    # Example logic for selecting source and target data centers with geographic considerations
    random_provider = random.choice(providers)
    source_dc = random.choice(random_provider.regions)
    target_dc = random.choice(random_provider.regions)

    # Include logic to prefer VMs in the same region if possible
    preferred_vms = [vm for vm in target_dc.vms if vm.region == source_dc.region]
    random_vm = random.choice(preferred_vms if preferred_vms else target_dc.vms)

    data_transfer_time = source_dc.calculate_data_transfer_time(task['size'], target_dc)
    env.process(random_vm.process_task(task, target_dc, data_transfer_time))
env.run()
# Out:
# VM VM_DC_Provider_1_US_1 processed Task 54 - Response Time=0.17229166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 36 - Response Time=0.18258333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 41 - Response Time=0.18337499999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 148 - Response Time=0.18337499999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 47 - Response Time=0.20395833333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 17 - Response Time=0.21583333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 151 - Response Time=0.240375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 35 - Response Time=0.24829166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 115 - Response Time=0.2744166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 95 - Response Time=0.27520833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 118 - Response Time=0.2886666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 72 - Response Time=0.297375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 156 - Response Time=0.314, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 13 - Response Time=0.31795833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 174 - Response Time=0.3219166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 191 - Response Time=0.333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 56 - Response Time=0.3615, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 92 - Response Time=0.3615, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 146 - Response Time=0.3622916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 105 - Response Time=0.3833333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 96 - Response Time=0.3892083333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 180 - Response Time=0.39166666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 10 - Response Time=0.4033333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 28 - Response Time=0.4058333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 38 - Response Time=0.406625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 143 - Response Time=0.41691666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3 - Response Time=0.4224583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 45 - Response Time=0.43500000000000005, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 29 - Response Time=0.44000000000000006, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 43 - Response Time=0.44225, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 30 - Response Time=0.458875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 57 - Response Time=0.46125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 93 - Response Time=0.46166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 175 - Response Time=0.46166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 122 - Response Time=0.46204166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 102 - Response Time=0.46499999999999997, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 162 - Response Time=0.473125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 66 - Response Time=0.4766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 5 - Response Time=0.48183333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 37 - Response Time=0.5008333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 8 - Response Time=0.501625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 126 - Response Time=0.5016666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 133 - Response Time=0.5032083333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 172 - Response Time=0.5055833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 176 - Response Time=0.5119166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 64 - Response Time=0.5127083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 128 - Response Time=0.5142916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 70 - Response Time=0.515, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 137 - Response Time=0.5174583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 91 - Response Time=0.5183333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 98 - Response Time=0.5214166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 168 - Response Time=0.5216666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 1 - Response Time=0.5283333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 78 - Response Time=0.5317083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 81 - Response Time=0.5333333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 194 - Response Time=0.5333333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 14 - Response Time=0.5366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 113 - Response Time=0.5366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 199 - Response Time=0.5633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 185 - Response Time=0.565, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 53 - Response Time=0.5720833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 34 - Response Time=0.572875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 104 - Response Time=0.5783333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 33 - Response Time=0.5792083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 71 - Response Time=0.585, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 193 - Response Time=0.585, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 181 - Response Time=0.5966666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 22 - Response Time=0.6083333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 170 - Response Time=0.6108750000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 179 - Response Time=0.6108750000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 75 - Response Time=0.6116666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 15 - Response Time=0.615, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 196 - Response Time=0.6187916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 141 - Response Time=0.62, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 21 - Response Time=0.6275000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 59 - Response Time=0.6283333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 39 - Response Time=0.6354166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 120 - Response Time=0.6366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 50 - Response Time=0.6449166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 100 - Response Time=0.645, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 87 - Response Time=0.6499999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 101 - Response Time=0.6528333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 177 - Response Time=0.6599583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 68 - Response Time=0.6639166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 18 - Response Time=0.6666666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 19 - Response Time=0.6670833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 160 - Response Time=0.6733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 4 - Response Time=0.6805416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 103 - Response Time=0.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 12 - Response Time=0.6916666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 58 - Response Time=0.701125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 82 - Response Time=0.7050000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 134 - Response Time=0.715375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 76 - Response Time=0.72, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 198 - Response Time=0.72, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 44 - Response Time=0.7224999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 99 - Response Time=0.7256666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 119 - Response Time=0.7366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 46 - Response Time=0.739125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 80 - Response Time=0.7416666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 83 - Response Time=0.745, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 73 - Response Time=0.7494166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 74 - Response Time=0.75, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 131 - Response Time=0.7612916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 109 - Response Time=0.7683333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 127 - Response Time=0.77, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 158 - Response Time=0.77, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 11 - Response Time=0.7716666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 152 - Response Time=0.7731666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 186 - Response Time=0.7810833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 6 - Response Time=0.78425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 187 - Response Time=0.7858333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 67 - Response Time=0.7883333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 190 - Response Time=0.7883333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 32 - Response Time=0.7916666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 159 - Response Time=0.7977083333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 94 - Response Time=0.8116666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 150 - Response Time=0.8200000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 139 - Response Time=0.8233333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 31 - Response Time=0.825, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 89 - Response Time=0.8316666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 171 - Response Time=0.8333333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 182 - Response Time=0.8566666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 49 - Response Time=0.8900000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 135 - Response Time=0.9016666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 107 - Response Time=0.9033333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 142 - Response Time=0.905, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 2 - Response Time=0.9133333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 121 - Response Time=0.9166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 147 - Response Time=0.9216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 24 - Response Time=0.9266666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 197 - Response Time=0.9283333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 163 - Response Time=0.9416666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 79 - Response Time=0.9783333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 136 - Response Time=1.0133333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 106 - Response Time=1.0233333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 155 - Response Time=1.025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 157 - Response Time=1.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 130 - Response Time=1.0566666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 188 - Response Time=1.07, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 42 - Response Time=1.0766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 183 - Response Time=1.1033333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 23 - Response Time=1.1216666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 9 - Response Time=1.1600000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 26 - Response Time=1.1633333333333336, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 140 - Response Time=1.175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 138 - Response Time=1.1816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 86 - Response Time=1.1966666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 25 - Response Time=1.2033333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 164 - Response Time=1.2033333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 173 - Response Time=1.21, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 27 - Response Time=1.2133333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 178 - Response Time=1.2183333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 111 - Response Time=1.2233333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 77 - Response Time=1.2283333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 20 - Response Time=1.2633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 117 - Response Time=1.2633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 184 - Response Time=1.2866666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 7 - Response Time=1.29, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 0 - Response Time=1.3066666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 60 - Response Time=1.3083333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 189 - Response Time=1.3333333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 125 - Response Time=1.3466666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 154 - Response Time=1.3466666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 90 - Response Time=1.3666666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 110 - Response Time=1.3683333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 69 - Response Time=1.3866666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 149 - Response Time=1.395, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 114 - Response Time=1.405, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 165 - Response Time=1.4066666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 161 - Response Time=1.4166666666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 84 - Response Time=1.4283333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 16 - Response Time=1.4416666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 85 - Response Time=1.4433333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 112 - Response Time=1.4466666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 144 - Response Time=1.4483333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_3 processed Task 52 - Response Time=1.4533333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 61 - Response Time=1.4633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 129 - Response Time=1.4633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 195 - Response Time=1.47, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 166 - Response Time=1.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 48 - Response Time=1.4866666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 167 - Response Time=1.49, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 88 - Response Time=1.5083333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 153 - Response Time=1.5116666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 116 - Response Time=1.5516666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 123 - Response Time=1.5666666666666669, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 145 - Response Time=1.5833333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 65 - Response Time=1.61, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 192 - Response Time=1.6233333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 51 - Response Time=1.6433333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 108 - Response Time=1.6549999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 55 - Response Time=1.6566666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 132 - Response Time=1.6666666666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 169 - Response Time=1.6683333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 63 - Response Time=1.6749999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 40 - Response Time=1.6766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 97 - Response Time=1.6983333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_4 processed Task 62 - Response Time=1.7066666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 124 - Response Time=1.7166666666666668, Penalty=0, Near Violation=False
