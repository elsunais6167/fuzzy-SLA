# %%
import simpy
import random
from sklearn.cluster import SpectralClustering
import numpy as np

class VirtualMachine:
    def __init__(self, env, id, processing_capability, num_cpus, ram, storage_capacity, data_center, region):
        self.env = env
        self.id = id
        self.processing_capability = processing_capability
        self.num_cpus = num_cpus
        self.ram = ram
        self.storage_capacity = storage_capacity
        self.data_center = data_center
        self.region = region
        self.uptime = 0
        self.total_time = 0
        self.data_access_log = {}
    
    def update_availability(self, time_passed):
        # Call this method periodically to update uptime and total_time
        self.total_time += time_passed  # Update with the actual time passed
        
    def get_availability(self):
        if self.total_time == 0:
            return 1  # Assuming always available when no time has passed
        return self.uptime / self.total_time
    
    def process_task(self, task, target_dc, data_transfer_time=0):
        start_time = self.env.now
        total_processing_time = task['size'] / self.processing_capability + data_transfer_time
        yield self.env.timeout(total_processing_time)
        end_time = self.env.now

        # Calculate response time and check for SLA violation or near violation
        response_time = end_time - start_time
        sla_rt = 180  # SLORT in seconds
        sla_ma = 0.95  # SLOMA in seconds
        w = 0.8  # Define the weight factor
        th_rt = w * sla_rt  # Threshold for near SLA violation

        penalty = 0
        near_violation = False
        if response_time > sla_rt:
            penalty = 0.0025  # Penalty per violation
        elif response_time > th_rt:
            near_violation = True  # Task is near to causing SLA violation

        cost = self.data_center.calculate_cost(task['size'], target_dc) - penalty
        self.data_center.total_revenue += (0.7 - penalty)  # Update total revenue for the data center
        self.data_center.near_violations += int(near_violation)  # Update near violations count for the data center

        self.data_access_log[task['id']] = {
            'response_time': response_time,
            'penalty': penalty,
            'near_violation': near_violation
        }
        print(f"VM {self.id} processed Task {task['id']} - Response Time={response_time}, Penalty={penalty}, Near Violation={near_violation}")
        
    def calculate_correlation_matrix(self, data_accessed, P):
        n = len(data_accessed)
        correlation_matrix = np.zeros((n, n))

        for i in range(n):
            for j in range(n):
                if i != j:
                    # T_k(di) is the set of tasks accessing data di
                    T_k_di = data_accessed[i]['tasks']
                    T_k_dj = data_accessed[j]['tasks']
                    common_tasks = len(set(T_k_di).intersection(set(T_k_dj)))
                    correlation_matrix[i, j] = common_tasks / P
                else:
                    correlation_matrix[i, j] = 0
        return correlation_matrix

    def perform_spectral_clustering(self, correlation_matrix, K):
        # Apply spectral clustering
        sc = SpectralClustering(n_clusters=K, affinity='precomputed')
        group_labels = sc.fit_predict(correlation_matrix)
        return group_labels

    def select_data_to_replicate(self, data_accessed, group_labels):
        # Calculate average access frequency for each group
        available_vms = [vm for vm in self.data_center.vms if vm.get_availability() >= self.slo_ma]
        unique_labels = set(group_labels)
        groups = {label: [] for label in unique_labels}

        for i, label in enumerate(group_labels):
            groups[label].append(data_accessed[i])

        data_to_replicate = []

        for label, group in groups.items():
            avg_freq = sum(d['access_frequency'] for d in group) / len(group)
            data_to_replicate.extend([d for d in group if d['access_frequency'] >= avg_freq])
            data_to_replicate = [d for d in data_to_replicate if self.is_in_same_region(d)]

        return data_to_replicate
    
    def is_in_same_region(self, data_item):
        # Logic to check if the data item is frequently accessed within the same region
        return all(vm.region == self.region for vm in data_item['accessing_vms'])
    
    # Update the adjust_replicas method to include the new strategy
    def adjust_replicas(self, P, K):
        # This list is populated with actual data accessed information
        data_accessed = [{'id': d, 'access_frequency': self.data_access_log[d]['access_frequency'], 'tasks': self.data_access_log[d]['tasks']} for d in self.data_access_log]
        
        correlation_matrix = self.calculate_correlation_matrix(data_accessed, P)
        group_labels = self.perform_spectral_clustering(correlation_matrix, K)
        data_to_replicate = self.select_data_to_replicate(data_accessed, group_labels)

        for data_item in data_to_replicate:
            # Find the best VM considering both response time and availability
            best_vm = self.find_best_vm_for_replication(data_item)
    
    def find_best_vm_for_replication(self, data_item):
        # Filter VMs based on storage capacity
        suitable_vms = [vm for vm in self.data_center.vms if vm.storage_capacity >= data_item['size'] and vm.get_availability() >= self.slo_ma]

        # Prioritize VMs in the same data center or region to minimize bandwidth costs and transfer time
        same_dc_vms = [vm for vm in suitable_vms if vm.data_center.id == self.data_center.id]
        same_region_vms = [vm for vm in suitable_vms if vm.region == self.region and vm not in same_dc_vms]

        # Select the best VM based on the lowest cost, prioritizing same DC, then same region
        best_vm = None

        if same_dc_vms:
            best_vm = min(same_dc_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        elif same_region_vms:
            best_vm = min(same_region_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        else:
            best_vm = min(suitable_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center)) if suitable_vms else None

        return best_vm

class DataCenter:
    def __init__(self, env, id, num_vms, vm_specs, pricing, bw_params, region):
        self.env = env
        self.id = id
        self.vm_specs = vm_specs
        self.pricing = pricing
        self.bw_params = bw_params
        self.total_revenue = 0
        self.near_violations = 0
        self.region = region
        self.vms = [VirtualMachine(env, f"VM_{id}_{i}", **vm_specs, data_center=self, region=self.region) for i in range(num_vms)]
    
    def get_total_revenue(self):
        return self.total_revenue
    
    def get_near_violations_count(self):
        return self.near_violations
    
    def calculate_cost(self, task_size, target_dc):
        cpu_cost = task_size / 107 * self.pricing['cpu_price']
        storage_cost = self.vm_specs['storage_capacity'] * self.pricing['storage_price']

        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_dc']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_region']
        else:
            # Inter-region transfer
            bw_cost = task_size * self.pricing['bw_price']['inter_region']

        return cpu_cost + storage_cost + bw_cost

    def calculate_data_transfer_time(self, task_size, target_dc):
        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_capacity = self.bw_params['intra_dc']['capacity']
            bw_delay = self.bw_params['intra_dc']['delay']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_capacity = self.bw_params['intra_region']['capacity']
            bw_delay = self.bw_params['intra_region']['delay']
        else:
            # Inter-region transfer
            bw_capacity = self.bw_params['inter_region']['capacity']
            bw_delay = self.bw_params['inter_region']['delay']

        data_transfer_time = task_size / bw_capacity + bw_delay / 1000  # Convert delay from ms to seconds
        return data_transfer_time

class CloudProvider:
    def __init__(self, env, id, num_regions, dcs_per_region, vm_specs, pricing, bw_params):
        self.env = env
        self.id = id
        self.pricing = pricing
        self.bw_params = bw_params
        region_keys = list(pricing.keys())  # Get the region keys from pricing
        self.regions = [DataCenter(env, f"DC_{id}_{region_keys[r]}", random.randint(*dcs_per_region), vm_specs, pricing[region_keys[r]], bw_params, region=region_keys[r]) for r in range(num_regions)]
    
    def find_target_dc(self, task):
        # Simplified logic: Randomly select a data center
        return random.choice(self.regions)

# Bandwidth parameters
bw_params = {
    'inter_region': {'capacity': 500, 'delay': 150},
    'intra_region': {'capacity': 1000, 'delay': 50},
    'intra_dc': {'capacity': 8000, 'delay': 10}
}

# Simulation parameters
num_providers = 3
num_regions = 3
dcs_per_provider = (2, 5)
num_vms_per_dc = 8
vm_specs = {
    'processing_capability': 1500,  # in MIPS
    'num_cpus': 2,
    'ram': 4,  # in Gb
    'storage_capacity': 8  # in Gb
}
num_data = 10000
task_size_range = (200, 1000)  # Task size range in MI

# Pricing structure
pricing = {
    'Provider_1': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.025, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.027, 'storage_price': 0.0066, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_2': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.018, 'storage_price': 0.008, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_3': {
        'US': {'cpu_price': 0.0095, 'storage_price': 0.0012, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.0090, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.0080, 'storage_price': 0.0090, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    }
}

env = simpy.Environment()
P = 32 # Number of violating tasks
K = 3 #Number of Cluster

providers = []
for i in range(num_providers):
    provider_key = f'Provider_{i+1}'  # This should match the keys in the pricing dictionary
    if provider_key in pricing:
        provider = CloudProvider(env, provider_key, num_regions, dcs_per_provider, vm_specs, pricing[provider_key], bw_params)
        providers.append(provider)
    else:
        print(f"Warning: Pricing not found for {provider_key}")
        
tasks = [{'id': i, 'size': random.randint(*task_size_range)} for i in range(num_data)]

#for provider in providers:
    #for dc in provider.regions:
        #print(f"Data Center {dc.id}: Total Revenue={dc.get_total_revenue()}, Near Violations={dc.get_near_violations_count()}")

for task in tasks:
    # Example logic for selecting source and target data centers with geographic considerations
    random_provider = random.choice(providers)
    source_dc = random.choice(random_provider.regions)
    target_dc = random.choice(random_provider.regions)

    # Include logic to prefer VMs in the same region if possible
    preferred_vms = [vm for vm in target_dc.vms if vm.region == source_dc.region]
    random_vm = random.choice(preferred_vms if preferred_vms else target_dc.vms)

    data_transfer_time = source_dc.calculate_data_transfer_time(task['size'], target_dc)
    env.process(random_vm.process_task(task, target_dc, data_transfer_time))
env.run()
# Out:
# VM VM_DC_Provider_3_US_1 processed Task 228 - Response Time=0.16833333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 633 - Response Time=0.16912500000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 623 - Response Time=0.1715, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 156 - Response Time=0.17229166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 865 - Response Time=0.17308333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 297 - Response Time=0.173875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 117 - Response Time=0.18020833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 245 - Response Time=0.18179166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 115 - Response Time=0.18337499999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 89 - Response Time=0.18416666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 590 - Response Time=0.18416666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 613 - Response Time=0.18416666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 872 - Response Time=0.1905, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 545 - Response Time=0.19208333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 63 - Response Time=0.192875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 435 - Response Time=0.19683333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 899 - Response Time=0.20158333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 26 - Response Time=0.20475000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 732 - Response Time=0.20475000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 420 - Response Time=0.20554166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 487 - Response Time=0.20554166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 942 - Response Time=0.20554166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 620 - Response Time=0.20791666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 384 - Response Time=0.20870833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 847 - Response Time=0.20870833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 728 - Response Time=0.20950000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 756 - Response Time=0.21029166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 838 - Response Time=0.211875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 210 - Response Time=0.21266666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 592 - Response Time=0.21266666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 844 - Response Time=0.21425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 520 - Response Time=0.21504166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 55 - Response Time=0.21820833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 85 - Response Time=0.219, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 934 - Response Time=0.22770833333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 268 - Response Time=0.2316666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 365 - Response Time=0.23245833333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 404 - Response Time=0.23245833333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 258 - Response Time=0.23404166666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 832 - Response Time=0.23404166666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 267 - Response Time=0.23483333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 884 - Response Time=0.23483333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 282 - Response Time=0.23720833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 449 - Response Time=0.23879166666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 422 - Response Time=0.23958333333333331, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 973 - Response Time=0.24275000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 415 - Response Time=0.245125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 170 - Response Time=0.2475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 248 - Response Time=0.2475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 855 - Response Time=0.24829166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 50 - Response Time=0.25145833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 119 - Response Time=0.25383333333333336, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 810 - Response Time=0.254625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 971 - Response Time=0.254625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 13 - Response Time=0.2554166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 311 - Response Time=0.2554166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 582 - Response Time=0.2554166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 82 - Response Time=0.25620833333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 281 - Response Time=0.25620833333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 87 - Response Time=0.26016666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 396 - Response Time=0.26095833333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 977 - Response Time=0.2649166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 266 - Response Time=0.2657083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 60 - Response Time=0.268875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 822 - Response Time=0.268875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 407 - Response Time=0.26966666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 506 - Response Time=0.27045833333333336, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 223 - Response Time=0.27125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 114 - Response Time=0.2720416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 622 - Response Time=0.273625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 489 - Response Time=0.27837500000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 891 - Response Time=0.28075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 764 - Response Time=0.283125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 304 - Response Time=0.28550000000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 80 - Response Time=0.2886666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 64 - Response Time=0.29262499999999997, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 208 - Response Time=0.295, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 14 - Response Time=0.30133333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 833 - Response Time=0.30291666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 916 - Response Time=0.3037083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 737 - Response Time=0.3052916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 255 - Response Time=0.30845833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 544 - Response Time=0.31004166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 366 - Response Time=0.31083333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 16 - Response Time=0.31320833333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 454 - Response Time=0.31320833333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 773 - Response Time=0.31320833333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 923 - Response Time=0.314, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 492 - Response Time=0.31479166666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 723 - Response Time=0.3155833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 303 - Response Time=0.31954166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 8 - Response Time=0.3235, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 392 - Response Time=0.32429166666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 327 - Response Time=0.32508333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 522 - Response Time=0.330625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 240 - Response Time=0.33379166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 247 - Response Time=0.33458333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 790 - Response Time=0.3425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 762 - Response Time=0.344875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 318 - Response Time=0.3464583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 264 - Response Time=0.3480416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 915 - Response Time=0.3480416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 316 - Response Time=0.34883333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 452 - Response Time=0.35120833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 967 - Response Time=0.35120833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 836 - Response Time=0.352, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 605 - Response Time=0.3575416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 643 - Response Time=0.35833333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 272 - Response Time=0.3630833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 694 - Response Time=0.3630833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 137 - Response Time=0.3646666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 402 - Response Time=0.36545833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 184 - Response Time=0.37179166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 766 - Response Time=0.37179166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 688 - Response Time=0.3725833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 252 - Response Time=0.37654166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 968 - Response Time=0.3789166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 969 - Response Time=0.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 102 - Response Time=0.3860416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 67 - Response Time=0.38666666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 387 - Response Time=0.3883333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 757 - Response Time=0.3883333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 843 - Response Time=0.38841666666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 153 - Response Time=0.3933333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 585 - Response Time=0.3933333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 924 - Response Time=0.3933333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 921 - Response Time=0.39475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 458 - Response Time=0.3955416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 583 - Response Time=0.3955416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 553 - Response Time=0.39666666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 569 - Response Time=0.397125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 54 - Response Time=0.3983333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 740 - Response Time=0.401875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 438 - Response Time=0.4026666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 852 - Response Time=0.4033333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 209 - Response Time=0.40504166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 805 - Response Time=0.40504166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 814 - Response Time=0.40504166666666663, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 239 - Response Time=0.4058333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 734 - Response Time=0.4058333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 348 - Response Time=0.40979166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 940 - Response Time=0.41000000000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 326 - Response Time=0.4116666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 430 - Response Time=0.4121666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 951 - Response Time=0.41333333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 9 - Response Time=0.41500000000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 880 - Response Time=0.41500000000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 892 - Response Time=0.41500000000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 185 - Response Time=0.41533333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 71 - Response Time=0.416125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 133 - Response Time=0.416125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 925 - Response Time=0.416125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 986 - Response Time=0.41770833333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 418 - Response Time=0.4192916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 539 - Response Time=0.42000000000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 352 - Response Time=0.4200833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 206 - Response Time=0.4216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 640 - Response Time=0.4216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 908 - Response Time=0.42333333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 713 - Response Time=0.42483333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 124 - Response Time=0.42500000000000004, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 689 - Response Time=0.4272083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 537 - Response Time=0.428, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 261 - Response Time=0.4287916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 214 - Response Time=0.43000000000000005, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 878 - Response Time=0.43037499999999995, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 563 - Response Time=0.4311666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 987 - Response Time=0.4316666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 3 - Response Time=0.43195833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 177 - Response Time=0.43195833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 525 - Response Time=0.43195833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 749 - Response Time=0.43274999999999997, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 362 - Response Time=0.4335416666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 189 - Response Time=0.4366666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 668 - Response Time=0.4366666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 905 - Response Time=0.4366666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 991 - Response Time=0.4366666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 683 - Response Time=0.4375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 136 - Response Time=0.44000000000000006, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 791 - Response Time=0.4406666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 386 - Response Time=0.44145833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 409 - Response Time=0.44225, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 476 - Response Time=0.44225, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 738 - Response Time=0.4433333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 444 - Response Time=0.44499999999999995, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 560 - Response Time=0.44499999999999995, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 955 - Response Time=0.4454166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 729 - Response Time=0.44666666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 779 - Response Time=0.44666666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 887 - Response Time=0.447, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 881 - Response Time=0.4483333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 475 - Response Time=0.44858333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 672 - Response Time=0.44858333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 628 - Response Time=0.44999999999999996, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 576 - Response Time=0.45095833333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 143 - Response Time=0.45166666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 225 - Response Time=0.4533333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 496 - Response Time=0.4533333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 952 - Response Time=0.45333333333333337, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 848 - Response Time=0.45491666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 107 - Response Time=0.45499999999999996, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 68 - Response Time=0.4583333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 679 - Response Time=0.4583333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 995 - Response Time=0.458875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 278 - Response Time=0.46499999999999997, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 552 - Response Time=0.46499999999999997, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 431 - Response Time=0.46520833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 198 - Response Time=0.46758333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 445 - Response Time=0.4683333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 627 - Response Time=0.4683333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 158 - Response Time=0.47233333333333327, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 416 - Response Time=0.47233333333333327, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 793 - Response Time=0.473125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 889 - Response Time=0.473125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 379 - Response Time=0.47550000000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 530 - Response Time=0.47550000000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 406 - Response Time=0.47629166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 159 - Response Time=0.47833333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 695 - Response Time=0.4794583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 241 - Response Time=0.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 717 - Response Time=0.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 818 - Response Time=0.48104166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 920 - Response Time=0.48104166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 425 - Response Time=0.4816666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 808 - Response Time=0.4816666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 257 - Response Time=0.4857916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 755 - Response Time=0.49, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 965 - Response Time=0.49, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 885 - Response Time=0.49054166666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 219 - Response Time=0.49212500000000003, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 566 - Response Time=0.49333333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 477 - Response Time=0.5, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 767 - Response Time=0.5, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 336 - Response Time=0.5033333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 393 - Response Time=0.504, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 555 - Response Time=0.5066666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 902 - Response Time=0.5127083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 294 - Response Time=0.5133333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 388 - Response Time=0.51825, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 912 - Response Time=0.51825, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 175 - Response Time=0.52, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 692 - Response Time=0.52, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 375 - Response Time=0.520625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 447 - Response Time=0.520625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 70 - Response Time=0.5216666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 763 - Response Time=0.5222083333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 642 - Response Time=0.5245833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 424 - Response Time=0.5269583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 238 - Response Time=0.53, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 429 - Response Time=0.53, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 459 - Response Time=0.53, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 909 - Response Time=0.530125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 697 - Response Time=0.5325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 935 - Response Time=0.5340833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 443 - Response Time=0.534875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 108 - Response Time=0.5364583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 213 - Response Time=0.5364583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 840 - Response Time=0.5364583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 581 - Response Time=0.5366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 665 - Response Time=0.5366666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 52 - Response Time=0.5380416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 173 - Response Time=0.54, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 775 - Response Time=0.5404166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 741 - Response Time=0.5427916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 631 - Response Time=0.5433333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 371 - Response Time=0.5449999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 179 - Response Time=0.5451666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 503 - Response Time=0.5459583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 853 - Response Time=0.5466666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 866 - Response Time=0.5466666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 290 - Response Time=0.5467500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 39 - Response Time=0.5499166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 83 - Response Time=0.5499166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 636 - Response Time=0.5499166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 985 - Response Time=0.5499166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 113 - Response Time=0.5515, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 200 - Response Time=0.5515, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 883 - Response Time=0.5515, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 929 - Response Time=0.5515, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 45 - Response Time=0.5516666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 941 - Response Time=0.5516666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 211 - Response Time=0.5522916666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 834 - Response Time=0.5533333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 10 - Response Time=0.553875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 491 - Response Time=0.553875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 428 - Response Time=0.5546666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 24 - Response Time=0.55625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 598 - Response Time=0.5566666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 719 - Response Time=0.5566666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 747 - Response Time=0.558625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 188 - Response Time=0.5594166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 815 - Response Time=0.5625833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 481 - Response Time=0.563375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 472 - Response Time=0.5641666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 37 - Response Time=0.5649583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 178 - Response Time=0.5649583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 193 - Response Time=0.565, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 527 - Response Time=0.565, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 501 - Response Time=0.56575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 147 - Response Time=0.5666666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 526 - Response Time=0.5666666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 786 - Response Time=0.568125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 509 - Response Time=0.5683333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 378 - Response Time=0.5697083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 837 - Response Time=0.5697083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 405 - Response Time=0.5720833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 589 - Response Time=0.5736666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 270 - Response Time=0.575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 337 - Response Time=0.5766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 850 - Response Time=0.5768333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 354 - Response Time=0.5776249999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 802 - Response Time=0.58, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 233 - Response Time=0.5807916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 301 - Response Time=0.5815833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 230 - Response Time=0.582375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 716 - Response Time=0.5833333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 858 - Response Time=0.5833333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 75 - Response Time=0.5839583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 128 - Response Time=0.5839583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 29 - Response Time=0.58475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 821 - Response Time=0.58475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 144 - Response Time=0.585, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 190 - Response Time=0.5855416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 517 - Response Time=0.5863333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 901 - Response Time=0.587125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 637 - Response Time=0.59, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 739 - Response Time=0.59, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 827 - Response Time=0.59, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 787 - Response Time=0.5916666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 831 - Response Time=0.5918749999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 53 - Response Time=0.595, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 651 - Response Time=0.595, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 397 - Response Time=0.5958333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 451 - Response Time=0.5966666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 456 - Response Time=0.5974166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 73 - Response Time=0.6, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 711 - Response Time=0.6, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 346 - Response Time=0.6005833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 460 - Response Time=0.6005833333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 81 - Response Time=0.6033333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 774 - Response Time=0.605, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 94 - Response Time=0.6053333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 139 - Response Time=0.6053333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 484 - Response Time=0.6053333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 357 - Response Time=0.6066666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 508 - Response Time=0.61, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 724 - Response Time=0.6108750000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 507 - Response Time=0.6116666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 616 - Response Time=0.6116666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 667 - Response Time=0.6133333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 289 - Response Time=0.6164166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 983 - Response Time=0.6164166666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 649 - Response Time=0.6166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 685 - Response Time=0.6166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 169 - Response Time=0.618, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 879 - Response Time=0.6211666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 556 - Response Time=0.6216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 946 - Response Time=0.6216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 222 - Response Time=0.62275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 250 - Response Time=0.6233333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 74 - Response Time=0.6243333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 359 - Response Time=0.6275000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 953 - Response Time=0.6282916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 958 - Response Time=0.6282916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 121 - Response Time=0.6283333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 389 - Response Time=0.63, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 490 - Response Time=0.6306666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 401 - Response Time=0.6316666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 989 - Response Time=0.63225, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 203 - Response Time=0.635, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 845 - Response Time=0.6362083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 735 - Response Time=0.637, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 455 - Response Time=0.6409583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 980 - Response Time=0.6433333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 62 - Response Time=0.6449166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 174 - Response Time=0.6457083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 199 - Response Time=0.6466666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 984 - Response Time=0.6466666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 498 - Response Time=0.6480833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 782 - Response Time=0.6488750000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 105 - Response Time=0.6499999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 604 - Response Time=0.6504583333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 376 - Response Time=0.6528333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 154 - Response Time=0.6544166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 698 - Response Time=0.6544166666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 286 - Response Time=0.6566666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 129 - Response Time=0.6583333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 77 - Response Time=0.658375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 799 - Response Time=0.6591666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 864 - Response Time=0.6599583333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 652 - Response Time=0.6607500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 20 - Response Time=0.6615416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 999 - Response Time=0.6631250000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 579 - Response Time=0.6647083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 851 - Response Time=0.6647083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 103 - Response Time=0.665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 370 - Response Time=0.6655, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 229 - Response Time=0.6666666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 610 - Response Time=0.667875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 696 - Response Time=0.6683333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 109 - Response Time=0.6686666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 130 - Response Time=0.6686666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 874 - Response Time=0.6699999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 957 - Response Time=0.6699999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 227 - Response Time=0.67025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 690 - Response Time=0.6716666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 765 - Response Time=0.6716666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 35 - Response Time=0.672625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 160 - Response Time=0.675, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 322 - Response Time=0.675, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 423 - Response Time=0.675, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 465 - Response Time=0.675, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 541 - Response Time=0.6757916666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 78 - Response Time=0.6765833333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 949 - Response Time=0.6766666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 846 - Response Time=0.6781666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 758 - Response Time=0.6799999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_2 processed Task 69 - Response Time=0.6805416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 152 - Response Time=0.6805416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 752 - Response Time=0.6805416666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 466 - Response Time=0.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 441 - Response Time=0.6833333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 84 - Response Time=0.685, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 974 - Response Time=0.685, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 499 - Response Time=0.6866666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 703 - Response Time=0.6866666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 932 - Response Time=0.6866666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 956 - Response Time=0.6866666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 933 - Response Time=0.6876666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 118 - Response Time=0.69, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 446 - Response Time=0.69, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 776 - Response Time=0.69, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 324 - Response Time=0.6916249999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 391 - Response Time=0.6916249999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 617 - Response Time=0.6916249999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 44 - Response Time=0.6916666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 204 - Response Time=0.6916666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 599 - Response Time=0.6932083333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 232 - Response Time=0.694, Penalty=0, Near Violation=False
# ...
# VM VM_DC_Provider_3_US_0 processed Task 759 - Response Time=1.4266666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 662 - Response Time=1.4300000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 432 - Response Time=1.4366666666666665, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 372 - Response Time=1.4383333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 950 - Response Time=1.4433333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 809 - Response Time=1.445, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 926 - Response Time=1.445, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 654 - Response Time=1.4466666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 906 - Response Time=1.4466666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 66 - Response Time=1.4516666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 221 - Response Time=1.4583333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 439 - Response Time=1.4616666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 629 - Response Time=1.4616666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 483 - Response Time=1.4633333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 419 - Response Time=1.4649999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 350 - Response Time=1.47, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 399 - Response Time=1.4716666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 167 - Response Time=1.475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 345 - Response Time=1.4766666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 536 - Response Time=1.4766666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 871 - Response Time=1.4766666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 664 - Response Time=1.4783333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 742 - Response Time=1.4783333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 606 - Response Time=1.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 197 - Response Time=1.4816666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 400 - Response Time=1.4816666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 485 - Response Time=1.4816666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 615 - Response Time=1.4833333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 347 - Response Time=1.4849999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 381 - Response Time=1.4866666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 440 - Response Time=1.4866666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 914 - Response Time=1.4866666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 478 - Response Time=1.4933333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 609 - Response Time=1.4966666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 893 - Response Time=1.505, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_3 processed Task 896 - Response Time=1.505, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 993 - Response Time=1.5066666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 161 - Response Time=1.5133333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 602 - Response Time=1.5166666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 670 - Response Time=1.5166666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 521 - Response Time=1.5183333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 276 - Response Time=1.5216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 307 - Response Time=1.5216666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 726 - Response Time=1.5233333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 339 - Response Time=1.5266666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 181 - Response Time=1.53, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 849 - Response Time=1.5316666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 202 - Response Time=1.5333333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 930 - Response Time=1.5333333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 367 - Response Time=1.54, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 377 - Response Time=1.5433333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 913 - Response Time=1.5483333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 897 - Response Time=1.5516666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 682 - Response Time=1.5533333333333335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 768 - Response Time=1.5550000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 236 - Response Time=1.5583333333333336, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 870 - Response Time=1.5583333333333336, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 292 - Response Time=1.5683333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 611 - Response Time=1.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 450 - Response Time=1.5716666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 680 - Response Time=1.5733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 295 - Response Time=1.5766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 59 - Response Time=1.5783333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 663 - Response Time=1.5783333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 417 - Response Time=1.58, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 994 - Response Time=1.58, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 600 - Response Time=1.5816666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 51 - Response Time=1.5916666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 548 - Response Time=1.5916666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 162 - Response Time=1.5933333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 806 - Response Time=1.5933333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_2 processed Task 816 - Response Time=1.5950000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 943 - Response Time=1.5966666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 182 - Response Time=1.5983333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 22 - Response Time=1.6, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 151 - Response Time=1.6, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 533 - Response Time=1.6, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 116 - Response Time=1.605, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 656 - Response Time=1.6083333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 859 - Response Time=1.6083333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 23 - Response Time=1.61, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 972 - Response Time=1.61, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 975 - Response Time=1.61, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 841 - Response Time=1.6116666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 6 - Response Time=1.6166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 531 - Response Time=1.6166666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 568 - Response Time=1.6183333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 794 - Response Time=1.6216666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 205 - Response Time=1.6233333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 275 - Response Time=1.625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 591 - Response Time=1.625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 746 - Response Time=1.625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_2 processed Task 577 - Response Time=1.6283333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 964 - Response Time=1.6283333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_4 processed Task 593 - Response Time=1.63, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_4 processed Task 648 - Response Time=1.63, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 857 - Response Time=1.6316666666666668, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 279 - Response Time=1.6333333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 976 - Response Time=1.6333333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 183 - Response Time=1.6349999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 19 - Response Time=1.6366666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 76 - Response Time=1.6383333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 512 - Response Time=1.6383333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 890 - Response Time=1.6400000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 704 - Response Time=1.6416666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 801 - Response Time=1.6416666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 40 - Response Time=1.6433333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 38 - Response Time=1.6483333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 702 - Response Time=1.6483333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 868 - Response Time=1.6483333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 235 - Response Time=1.6516666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 540 - Response Time=1.6516666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 570 - Response Time=1.6516666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_3 processed Task 575 - Response Time=1.6533333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 191 - Response Time=1.6583333333333332, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 919 - Response Time=1.6600000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 584 - Response Time=1.6616666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 639 - Response Time=1.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 249 - Response Time=1.6733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 265 - Response Time=1.6733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 356 - Response Time=1.6733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 519 - Response Time=1.6733333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_2 processed Task 727 - Response Time=1.6749999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 333 - Response Time=1.6766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 505 - Response Time=1.6766666666666667, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 145 - Response Time=1.6800000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_3 processed Task 218 - Response Time=1.6800000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 408 - Response Time=1.6800000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 448 - Response Time=1.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 596 - Response Time=1.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 669 - Response Time=1.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_2 processed Task 684 - Response Time=1.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 812 - Response Time=1.6816666666666666, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 5 - Response Time=1.6916666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_3 processed Task 141 - Response Time=1.6916666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 216 - Response Time=1.6916666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 300 - Response Time=1.6916666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 813 - Response Time=1.6916666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 138 - Response Time=1.6949999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_3 processed Task 27 - Response Time=1.6983333333333333, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 207 - Response Time=1.705, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_2 processed Task 820 - Response Time=1.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 706 - Response Time=1.7116666666666664, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 434 - Response Time=1.7133333333333334, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_4 processed Task 142 - Response Time=1.7149999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 882 - Response Time=1.7166666666666668, Penalty=0, Near Violation=False
