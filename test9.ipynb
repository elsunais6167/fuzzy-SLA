# %%
import simpy
import random
from sklearn.cluster import SpectralClustering
import numpy as np

class VirtualMachine:
    def __init__(self, env, id, processing_capability, num_cpus, ram, storage_capacity, data_center, region):
        self.env = env
        self.id = id
        self.processing_capability = processing_capability
        self.num_cpus = num_cpus
        self.ram = ram
        self.storage_capacity = storage_capacity
        self.data_center = data_center
        self.region = region
        self.uptime = 0
        self.total_time = 0
        self.data_access_log = {}
    
    def update_availability(self, time_passed):
        # Call this method periodically to update uptime and total_time
        self.total_time += time_passed  # Update with the actual time passed
        
    def get_availability(self):
        if self.total_time == 0:
            return 1  # Assuming always available when no time has passed
        return self.uptime / self.total_time
    
    def process_task(self, task, target_dc, data_transfer_time=0):
        start_time = self.env.now
        total_processing_time = task['size'] / self.processing_capability + data_transfer_time
        yield self.env.timeout(total_processing_time)
        end_time = self.env.now

        # Calculate response time and check for SLA violation or near violation
        rst = end_time - start_time
        response_time = rst * 60
        sla_rt = 60  # SLORT in seconds
        sla_ma = 0.95  # SLOMA in seconds
        w = 0.8  # Define the weight factor
        th_rt = w * sla_rt  # Threshold for near SLA violation

        penalty = 0
        near_violation = False
        if response_time > sla_rt:
            penalty = 0.0025  # Penalty per violation
        elif response_time > th_rt:
            near_violation = True  # Task is near to causing SLA violation

        cost = self.data_center.calculate_cost(task['size'], target_dc) - penalty
        self.data_center.total_revenue += (0.7 - penalty)  # Update total revenue for the data center
        self.data_center.near_violations += int(near_violation)  # Update near violations count for the data center

        self.data_access_log[task['id']] = {
            'response_time': response_time,
            'penalty': penalty,
            'near_violation': near_violation
        }
        print(f"VM {self.id} processed Task {task['id']} - Response Time={response_time}, Penalty={penalty}, Near Violation={near_violation}")
        
    def calculate_correlation_matrix(self, data_accessed, P):
        n = len(data_accessed)
        correlation_matrix = np.zeros((n, n))

        for i in range(n):
            for j in range(n):
                if i != j:
                    # T_k(di) is the set of tasks accessing data di
                    T_k_di = data_accessed[i]['tasks']
                    T_k_dj = data_accessed[j]['tasks']
                    common_tasks = len(set(T_k_di).intersection(set(T_k_dj)))
                    correlation_matrix[i, j] = common_tasks / P
                else:
                    correlation_matrix[i, j] = 0
        return correlation_matrix

    def perform_spectral_clustering(self, correlation_matrix, K):
        # Apply spectral clustering
        sc = SpectralClustering(n_clusters=K, affinity='precomputed')
        group_labels = sc.fit_predict(correlation_matrix)
        return group_labels

    def select_data_to_replicate(self, data_accessed, group_labels):
        # Calculate average access frequency for each group
        available_vms = [vm for vm in self.data_center.vms if vm.get_availability() >= self.slo_ma]
        unique_labels = set(group_labels)
        groups = {label: [] for label in unique_labels}

        for i, label in enumerate(group_labels):
            groups[label].append(data_accessed[i])

        data_to_replicate = []

        for label, group in groups.items():
            avg_freq = sum(d['access_frequency'] for d in group) / len(group)
            data_to_replicate.extend([d for d in group if d['access_frequency'] >= avg_freq])
            data_to_replicate = [d for d in data_to_replicate if self.is_in_same_region(d)]

        return data_to_replicate
    
    def is_in_same_region(self, data_item):
        # Logic to check if the data item is frequently accessed within the same region
        return all(vm.region == self.region for vm in data_item['accessing_vms'])
    
    # Update the adjust_replicas method to include the new strategy
    def adjust_replicas(self, P, K):
        # This list is populated with actual data accessed information
        data_accessed = [{'id': d, 'access_frequency': self.data_access_log[d]['access_frequency'], 'tasks': self.data_access_log[d]['tasks']} for d in self.data_access_log]
        
        correlation_matrix = self.calculate_correlation_matrix(data_accessed, P)
        group_labels = self.perform_spectral_clustering(correlation_matrix, K)
        data_to_replicate = self.select_data_to_replicate(data_accessed, group_labels)

        for data_item in data_to_replicate:
            # Find the best VM considering both response time and availability
            best_vm = self.find_best_vm_for_replication(data_item)
    
    def find_best_vm_for_replication(self, data_item):
        # Filter VMs based on storage capacity
        suitable_vms = [vm for vm in self.data_center.vms if vm.storage_capacity >= data_item['size'] and vm.get_availability() >= self.slo_ma]

        # Prioritize VMs in the same data center or region to minimize bandwidth costs and transfer time
        same_dc_vms = [vm for vm in suitable_vms if vm.data_center.id == self.data_center.id]
        same_region_vms = [vm for vm in suitable_vms if vm.region == self.region and vm not in same_dc_vms]

        # Select the best VM based on the lowest cost, prioritizing same DC, then same region
        best_vm = None

        if same_dc_vms:
            best_vm = min(same_dc_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        elif same_region_vms:
            best_vm = min(same_region_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center))
        else:
            best_vm = min(suitable_vms, key=lambda vm: self.data_center.calculate_cost(data_item['size'], vm.data_center)) if suitable_vms else None

        return best_vm

class DataCenter:
    def __init__(self, env, id, num_vms, vm_specs, pricing, bw_params, region):
        self.env = env
        self.id = id
        self.vm_specs = vm_specs
        self.pricing = pricing
        self.bw_params = bw_params
        self.total_revenue = 0
        self.near_violations = 0
        self.region = region
        self.vms = [VirtualMachine(env, f"VM_{id}_{i}", **vm_specs, data_center=self, region=self.region) for i in range(num_vms)]
    
    def get_total_revenue(self):
        return self.total_revenue
    
    def get_near_violations_count(self):
        return self.near_violations
    
    def calculate_cost(self, task_size, target_dc):
        cpu_cost = task_size / 107 * self.pricing['cpu_price']
        storage_cost = self.vm_specs['storage_capacity'] * self.pricing['storage_price']
 
        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_dc']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_cost = task_size * self.pricing['bw_price']['intra_region']
        else:
            # Inter-region transfer
            bw_cost = task_size * self.pricing['bw_price']['inter_region']

        return cpu_cost + storage_cost + bw_cost

    def calculate_data_transfer_time(self, task_size, target_dc):
        if self.id == target_dc.id:
            # Intra-DC transfer
            bw_capacity = self.bw_params['intra_dc']['capacity']
            bw_delay = self.bw_params['intra_dc']['delay']
        elif self.id.split('_')[1] == target_dc.id.split('_')[1]:
            # Intra-region transfer
            bw_capacity = self.bw_params['intra_region']['capacity']
            bw_delay = self.bw_params['intra_region']['delay']
        else:
            # Inter-region transfer
            bw_capacity = self.bw_params['inter_region']['capacity']
            bw_delay = self.bw_params['inter_region']['delay']

        data_transfer_time = task_size / bw_capacity + bw_delay / 1000  # Convert delay from ms to seconds
        return data_transfer_time

class CloudProvider:
    def __init__(self, env, id, num_regions, dcs_per_region, vm_specs, pricing, bw_params):
        self.env = env
        self.id = id
        self.pricing = pricing
        self.bw_params = bw_params
        region_keys = list(pricing.keys())  # Get the region keys from pricing
        self.regions = [DataCenter(env, f"DC_{id}_{region_keys[r]}", random.randint(*dcs_per_region), vm_specs, pricing[region_keys[r]], bw_params, region=region_keys[r]) for r in range(num_regions)]
    
    def find_target_dc(self, task):
        # Simplified logic: Randomly select a data center
        return random.choice(self.regions)

# Bandwidth parameters
bw_params = {
    'inter_region': {'capacity': 500, 'delay': 150},
    'intra_region': {'capacity': 1000, 'delay': 50},
    'intra_dc': {'capacity': 8000, 'delay': 10}
}

# Simulation parameters
num_providers = 3
num_regions = 3
dcs_per_provider = (2, 5)
num_vms_per_dc = 8
vm_specs = {
    'processing_capability': 1500,  # in MIPS
    'num_cpus': 2,
    'ram': 4,  # in Gb
    'storage_capacity': 8  # in Gb
}
num_data = 10000
task_size_range = (200, 1000)  # Task size range in MI

# Pricing structure
pricing = {
    'Provider_1': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.025, 'storage_price': 0.006, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.027, 'storage_price': 0.0066, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_2': {
        'US': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.018, 'storage_price': 0.008, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.020, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    },
    'Provider_3': {
        'US': {'cpu_price': 0.0095, 'storage_price': 0.0012, 'bw_price': {'intra_dc': 0.001, 'inter_region': 0.008}},
        'EU': {'cpu_price': 0.0090, 'storage_price': 0.0096, 'bw_price': {'intra_dc': 0.0015, 'inter_region': 0.008}},
        'AS': {'cpu_price': 0.0080, 'storage_price': 0.0090, 'bw_price': {'intra_dc': 0.002, 'inter_region': 0.008}}
    }
}

env = simpy.Environment()
P = 32 # Number of violating tasks
K = 3 #Number of Cluster

providers = []
for i in range(num_providers):
    provider_key = f'Provider_{i+1}'  # This should match the keys in the pricing dictionary
    if provider_key in pricing:
        provider = CloudProvider(env, provider_key, num_regions, dcs_per_provider, vm_specs, pricing[provider_key], bw_params)
        providers.append(provider)
    else:
        print(f"Warning: Pricing not found for {provider_key}")
        
tasks = [{'id': i, 'size': random.randint(*task_size_range)} for i in range(num_data)]

#for provider in providers:
    #for dc in provider.regions:
        #print(f"Data Center {dc.id}: Total Revenue={dc.get_total_revenue()}, Near Violations={dc.get_near_violations_count()}")

for task in tasks:
    # Example logic for selecting source and target data centers with geographic considerations
    random_provider = random.choice(providers)
    source_dc = random.choice(random_provider.regions)
    target_dc = random.choice(random_provider.regions)

    # Include logic to prefer VMs in the same region if possible
    preferred_vms = [vm for vm in target_dc.vms if vm.region == source_dc.region]
    random_vm = random.choice(preferred_vms if preferred_vms else target_dc.vms)

    data_transfer_time = source_dc.calculate_data_transfer_time(task['size'], target_dc)
    env.process(random_vm.process_task(task, target_dc, data_transfer_time))
env.run()
# Out:
# VM VM_DC_Provider_1_US_1 processed Task 9034 - Response Time=10.1, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 9609 - Response Time=10.1, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 1213 - Response Time=10.1475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1771 - Response Time=10.1475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 5000 - Response Time=10.1475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6537 - Response Time=10.1475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 8763 - Response Time=10.1475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 2526 - Response Time=10.195, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 5396 - Response Time=10.195, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 5734 - Response Time=10.195, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 8141 - Response Time=10.195, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 245 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 2214 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 4185 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6351 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 8158 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 9017 - Response Time=10.242500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 2341 - Response Time=10.290000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 3920 - Response Time=10.290000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 5151 - Response Time=10.290000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 9885 - Response Time=10.290000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 934 - Response Time=10.337499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 2740 - Response Time=10.337499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 4124 - Response Time=10.337499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 7872 - Response Time=10.337499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 8145 - Response Time=10.337499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 2051 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 2238 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 2918 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 3248 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3429 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 5782 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 9882 - Response Time=10.385, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 1378 - Response Time=10.432500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1413 - Response Time=10.432500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6276 - Response Time=10.432500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6706 - Response Time=10.432500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 7020 - Response Time=10.432500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3460 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 5249 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 5373 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 5841 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 7443 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 9644 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 9762 - Response Time=10.48, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 417 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 4127 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 4846 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 5075 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 5602 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 7684 - Response Time=10.5275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 3087 - Response Time=10.575000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 3517 - Response Time=10.575000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3587 - Response Time=10.575000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 4812 - Response Time=10.622499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 5197 - Response Time=10.622499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 8576 - Response Time=10.622499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 8808 - Response Time=10.622499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1094 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2142 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 3446 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 8029 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 8202 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 9106 - Response Time=10.67, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 403 - Response Time=10.7175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4554 - Response Time=10.7175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 7116 - Response Time=10.765, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8285 - Response Time=10.765, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 9968 - Response Time=10.765, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 608 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 4122 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 4975 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 5308 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 5876 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8951 - Response Time=10.8125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 1180 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 3311 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3970 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 4092 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4457 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 6791 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 7707 - Response Time=10.86, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 167 - Response Time=10.907499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 3249 - Response Time=10.955, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 5069 - Response Time=10.955, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 5593 - Response Time=10.955, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 8334 - Response Time=10.955, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 1209 - Response Time=11.0025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 1396 - Response Time=11.0025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 1541 - Response Time=11.0025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 6865 - Response Time=11.0025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3014 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 3432 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 4361 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 6847 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 7963 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8216 - Response Time=11.05, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 609 - Response Time=11.0975, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 3673 - Response Time=11.0975, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 4234 - Response Time=11.0975, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 313 - Response Time=11.145, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 4066 - Response Time=11.145, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 5951 - Response Time=11.145, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 6709 - Response Time=11.145, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 9957 - Response Time=11.145, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 9478 - Response Time=11.192499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 9706 - Response Time=11.192499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 3402 - Response Time=11.240000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 7201 - Response Time=11.240000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 7910 - Response Time=11.240000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8147 - Response Time=11.240000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 9870 - Response Time=11.240000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 343 - Response Time=11.2875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1058 - Response Time=11.2875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 1364 - Response Time=11.2875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 6685 - Response Time=11.2875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 9256 - Response Time=11.2875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 1329 - Response Time=11.335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 1858 - Response Time=11.335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 1895 - Response Time=11.335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 5448 - Response Time=11.335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9854 - Response Time=11.335, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 3124 - Response Time=11.382499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 4398 - Response Time=11.382499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 4916 - Response Time=11.382499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 6125 - Response Time=11.382499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3171 - Response Time=11.43, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 3256 - Response Time=11.43, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 6144 - Response Time=11.43, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 8569 - Response Time=11.43, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 7725 - Response Time=11.4775, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 1318 - Response Time=11.525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 1343 - Response Time=11.525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 6914 - Response Time=11.525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 8075 - Response Time=11.525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 8737 - Response Time=11.525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 255 - Response Time=11.5725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 55 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 190 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 5715 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 5798 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 7468 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 8726 - Response Time=11.620000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 371 - Response Time=11.667499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 2100 - Response Time=11.667499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 361 - Response Time=11.715, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 6523 - Response Time=11.715, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 7293 - Response Time=11.715, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 9132 - Response Time=11.715, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 2392 - Response Time=11.7625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 2894 - Response Time=11.7625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 4439 - Response Time=11.7625, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 2622 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2648 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5508 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6862 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 8094 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 9366 - Response Time=11.81, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 7995 - Response Time=11.8575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 9647 - Response Time=11.8575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 3144 - Response Time=11.905000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 5763 - Response Time=11.905000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 8937 - Response Time=11.905000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 9219 - Response Time=11.905000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 572 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 1959 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 3452 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4646 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 4774 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 6165 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 8482 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 9313 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 9585 - Response Time=11.952499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 4826 - Response Time=12.0, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4838 - Response Time=12.0, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 5517 - Response Time=12.0, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 9378 - Response Time=12.0, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 4331 - Response Time=12.047500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 5541 - Response Time=12.047500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 7253 - Response Time=12.047500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 7876 - Response Time=12.047500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4648 - Response Time=12.095, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5299 - Response Time=12.095, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6401 - Response Time=12.095, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 8311 - Response Time=12.095, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 9261 - Response Time=12.095, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 181 - Response Time=12.1425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 3760 - Response Time=12.1425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 5696 - Response Time=12.1425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 7836 - Response Time=12.1425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 9886 - Response Time=12.1425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 293 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 1092 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 1360 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3695 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 7683 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8503 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8504 - Response Time=12.19, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 440 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 1600 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 2631 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 3346 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 3569 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 3661 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 4782 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 7370 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 8098 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 8109 - Response Time=12.237499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 1851 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 4301 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 5382 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 5756 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 6902 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 9598 - Response Time=12.285, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 3116 - Response Time=12.3325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 9690 - Response Time=12.3325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 2772 - Response Time=12.38, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 4069 - Response Time=12.38, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 8345 - Response Time=12.38, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 2286 - Response Time=12.4275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 8916 - Response Time=12.4275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 9150 - Response Time=12.4275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 755 - Response Time=12.475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 4855 - Response Time=12.475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 2163 - Response Time=12.522499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 6425 - Response Time=12.522499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 8306 - Response Time=12.522499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 8608 - Response Time=12.522499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 288 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 1103 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 2374 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 6689 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 7349 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 7800 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8175 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 9737 - Response Time=12.57, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6462 - Response Time=12.6175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 6517 - Response Time=12.6175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 7139 - Response Time=12.6175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9049 - Response Time=12.6175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 1169 - Response Time=12.665000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 8718 - Response Time=12.665000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3131 - Response Time=12.7125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5357 - Response Time=12.7125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 6519 - Response Time=12.7125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 7805 - Response Time=12.7125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8291 - Response Time=12.7125, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 2944 - Response Time=12.76, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2400 - Response Time=12.8075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 2513 - Response Time=12.8075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 3138 - Response Time=12.8075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 3627 - Response Time=12.8075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 4412 - Response Time=12.8075, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7863 - Response Time=12.855, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 8377 - Response Time=12.855, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 9832 - Response Time=12.855, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 1930 - Response Time=12.9025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 3494 - Response Time=12.9025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 4609 - Response Time=12.9025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5049 - Response Time=12.9025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8337 - Response Time=12.9025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 3290 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 3406 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3407 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 4080 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 4713 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 6581 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 7625 - Response Time=12.950000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 1999 - Response Time=12.997499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 3538 - Response Time=12.997499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 3891 - Response Time=12.997499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 9217 - Response Time=12.997499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 998 - Response Time=13.045, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 3445 - Response Time=13.045, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5055 - Response Time=13.045, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 7838 - Response Time=13.045, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 308 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 2901 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 3971 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 5543 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 6897 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 8371 - Response Time=13.092500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3999 - Response Time=13.14, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 1004 - Response Time=13.1875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 4920 - Response Time=13.1875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 5911 - Response Time=13.1875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 8197 - Response Time=13.1875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 8241 - Response Time=13.1875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 971 - Response Time=13.235000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 2146 - Response Time=13.235000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3132 - Response Time=13.235000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 7128 - Response Time=13.235000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 9284 - Response Time=13.235000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9899 - Response Time=13.282499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 8037 - Response Time=13.33, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 9689 - Response Time=13.33, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 555 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 1093 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2492 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 3819 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 5084 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 6126 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 7103 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 7373 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8406 - Response Time=13.377500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 612 - Response Time=13.425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 1633 - Response Time=13.425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 5228 - Response Time=13.425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 7835 - Response Time=13.425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 1567 - Response Time=13.4725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 3964 - Response Time=13.4725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 8539 - Response Time=13.4725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9613 - Response Time=13.4725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9692 - Response Time=13.4725, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 4355 - Response Time=13.520000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 6002 - Response Time=13.520000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 6400 - Response Time=13.520000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 207 - Response Time=13.567499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 4252 - Response Time=13.567499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 6803 - Response Time=13.567499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 8153 - Response Time=13.567499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 1806 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 3317 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 4781 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 6019 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 6597 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 9020 - Response Time=13.71, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 3659 - Response Time=13.7575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 4049 - Response Time=13.7575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 4654 - Response Time=13.7575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5585 - Response Time=13.7575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 8811 - Response Time=13.7575, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 6652 - Response Time=13.805, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 7985 - Response Time=13.805, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 9727 - Response Time=13.805, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 8538 - Response Time=13.8525, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 265 - Response Time=13.900000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 4428 - Response Time=13.900000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 9546 - Response Time=13.900000000000002, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 728 - Response Time=13.9475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 4860 - Response Time=13.9475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 5984 - Response Time=13.9475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 9579 - Response Time=13.9475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 9777 - Response Time=13.9475, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 4319 - Response Time=13.995000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 4473 - Response Time=13.995000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 5774 - Response Time=13.995000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 9984 - Response Time=13.995000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 211 - Response Time=14.0425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 406 - Response Time=14.0425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 9817 - Response Time=14.0425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 9821 - Response Time=14.0425, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 1854 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 3155 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 3880 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3997 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 4791 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5701 - Response Time=14.09, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 1259 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 2237 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 3021 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 3102 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6148 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 7584 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 8616 - Response Time=14.1375, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3629 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 3718 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6770 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 7994 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 8801 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 8824 - Response Time=14.185, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 1230 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3187 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 4403 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 4644 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 4799 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 7484 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7756 - Response Time=14.2325, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 4070 - Response Time=14.28, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 4327 - Response Time=14.28, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 5979 - Response Time=14.28, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 6380 - Response Time=14.28, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 8226 - Response Time=14.28, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 1216 - Response Time=14.3275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3861 - Response Time=14.3275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 4670 - Response Time=14.3275, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 1472 - Response Time=14.374999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 1988 - Response Time=14.374999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 3862 - Response Time=14.4225, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 34 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 3716 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 5017 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 5047 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 5916 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 6049 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 7840 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 9483 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 9780 - Response Time=14.469999999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 2930 - Response Time=14.5175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 3522 - Response Time=14.5175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 4208 - Response Time=14.5175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 7053 - Response Time=14.5175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7853 - Response Time=14.5175, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 588 - Response Time=14.565000000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 760 - Response Time=14.612499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 2313 - Response Time=14.612499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 7331 - Response Time=14.612499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 4589 - Response Time=14.66, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7510 - Response Time=14.66, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 9466 - Response Time=14.66, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 1125 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 4020 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 6354 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 7453 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7511 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 7814 - Response Time=14.707500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 1166 - Response Time=14.755, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 4717 - Response Time=14.755, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5691 - Response Time=14.755, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 3190 - Response Time=14.8025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 3246 - Response Time=14.8025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 3843 - Response Time=14.8025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 7316 - Response Time=14.8025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 9569 - Response Time=14.8025, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 722 - Response Time=14.85, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 2029 - Response Time=14.85, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 4482 - Response Time=14.85, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 4625 - Response Time=14.85, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5296 - Response Time=14.85, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 1405 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 3680 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3784 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 6193 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 6194 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 6289 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 8665 - Response Time=14.897499999999999, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 1150 - Response Time=14.945, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 8789 - Response Time=14.945, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 1524 - Response Time=14.992500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 5215 - Response Time=14.992500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 6259 - Response Time=14.992500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 8215 - Response Time=14.992500000000001, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 918 - Response Time=15.04, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 3213 - Response Time=15.04, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 3622 - Response Time=15.04, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 563 - Response Time=15.0875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 606 - Response Time=15.0875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 5907 - Response Time=15.0875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 7265 - Response Time=15.0875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 9350 - Response Time=15.0875, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1902 - Response Time=15.134999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 6063 - Response Time=15.134999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 6772 - Response Time=15.134999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 6834 - Response Time=15.134999999999998, Penalty=0, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 6979 - Response Time=15.134999999999998, Penalty=0, Near Violation=False
# ...
# VM VM_DC_Provider_3_US_1 processed Task 7433 - Response Time=101.3, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 7909 - Response Time=101.3, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 8752 - Response Time=101.3, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 9472 - Response Time=101.3, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 428 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 1257 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 3683 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 4083 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 5409 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 7105 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 7114 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 7679 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 8572 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 8727 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 9434 - Response Time=101.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 623 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 1313 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 1326 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 1566 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 3049 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 4154 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 7752 - Response Time=101.49999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 4522 - Response Time=101.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 4652 - Response Time=101.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 5080 - Response Time=101.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 8392 - Response Time=101.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 2480 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 3657 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 3708 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 7258 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 9643 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9782 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 9972 - Response Time=101.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 3383 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 4731 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5142 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5553 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 6216 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 7070 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 7328 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 8320 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 9481 - Response Time=101.80000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 1335 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 2645 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 4922 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 5443 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 5473 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 5507 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 6821 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 9906 - Response Time=101.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 7 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2543 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3296 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 3553 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 4051 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 5037 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 5770 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 6428 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 6704 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 8290 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 9412 - Response Time=102.00000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 2523 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 3181 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4338 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 4500 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 6850 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 8114 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 9072 - Response Time=102.1, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 3103 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 5627 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 5641 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6603 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_0 processed Task 7047 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 7753 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 8129 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 9425 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 9520 - Response Time=102.2, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 3688 - Response Time=102.30000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 7006 - Response Time=102.30000000000001, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 1301 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 1511 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 3182 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 4388 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 4543 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 6210 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 6464 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 6653 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 8434 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_1 processed Task 9083 - Response Time=102.39999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 477 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 1080 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 1232 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 2331 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 3898 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 5356 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 5893 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 7768 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_2 processed Task 8549 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 8849 - Response Time=102.5, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 2267 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_3 processed Task 3800 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 5717 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 6250 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_2 processed Task 7354 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 7586 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 8997 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 9162 - Response Time=102.6, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_1 processed Task 2975 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_1 processed Task 3499 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 4350 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 4436 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 5619 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 6673 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_0 processed Task 6722 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 7749 - Response Time=102.69999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 518 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_2 processed Task 724 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_1 processed Task 869 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 3098 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_0 processed Task 3268 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 3634 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 7727 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_0 processed Task 8072 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 9467 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_AS_1 processed Task 9766 - Response Time=102.8, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 142 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_4 processed Task 1636 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 2097 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 2219 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_1 processed Task 3242 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_1 processed Task 4701 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 4718 - Response Time=102.89999999999999, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 225 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_EU_0 processed Task 274 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_AS_0 processed Task 3373 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_US_0 processed Task 4050 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_US_0 processed Task 4203 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 5934 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_2_US_0 processed Task 6614 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_EU_3 processed Task 7132 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_1_AS_1 processed Task 8422 - Response Time=103.0, Penalty=0.0025, Near Violation=False
# VM VM_DC_Provider_3_EU_1 processed Task 9107 - Response Time=103.0, Penalty=0.0025, Near Violation=False
